# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import os
# Out:
# 2023-12-25 10:07:57.945517: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-25 10:07:58.747519: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def checkfilepath(filepath):
    return os.path.exists(filepath)

# %%
df = pd.read_excel('/lfs1/ashaji/Imputation_Problem/data/ADNI_final.xlsx', engine='openpyxl')
df['SubjID'].replace('',np.nan,inplace=True)
df['AGE_at_scan'].replace('',np.nan,inplace=True)
df.dropna(subset=['SubjID','AGE_at_scan'], inplace=True)
df = df.reset_index(drop=True)
df.loc[df['SEX']=='M','SEX'] = 1
df.loc[df['SEX']=='F','SEX'] = 0
condCN = df['DX'] == 'CN'
df = df.sort_values(by = ['SubjID'])
df = df.loc[condCN,:]
# df = df.sample(frac = 1)
df = df.reset_index(drop=True)

# %%
df['SEX'].replace('',np.nan,inplace=True)
df['CDRSB'].replace('',np.nan,inplace=True)
df['ADAS11'].replace('',np.nan,inplace=True)
df['ADAS13'].replace('',np.nan,inplace=True)
df['MMSE'].replace('',np.nan,inplace=True)
df['MOCA'].replace('',np.nan,inplace=True)
df['APOE A1'].replace('',np.nan,inplace=True)
df['APOE A2'].replace('',np.nan,inplace=True)

# %%
cond = [checkfilepath(str(x)) for x in df['ACCEL_DL_6DOF_2MM_T1']]
cond0 = df['ACCEL_Preprocessed for DL?']=='yes'

# %%
conddwi = [checkfilepath(str(x)) for x in df['DWI_Matched_File_FA_Path_ENIGMATBSSspace_2MM']]

# %%
len(conddwi)
# Out:
# 3288

# %%
cond2 = df['SEX'].isnull()
cond2 = np.invert(cond2)
cond3 = df['CDRSB'].isnull()
cond3 = np.invert(cond3)
cond4 = df['ADAS11'].isnull()
cond4 = np.invert(cond4)
cond5 = df['ADAS13'].isnull()
cond5 = np.invert(cond5)
cond6 = df['MMSE'].isnull()
cond6 = np.invert(cond6)
cond7 = df['MOCA'].isnull()
cond7 = np.invert(cond7)
cond8 = df['APOE A1'].isnull()
cond8 = np.invert(cond8)
cond9 = df['APOE A2'].isnull()
cond9 = np.invert(cond9)

# %%
condt1 = [cond[i] & cond0[i]  for i in range(len(cond))]

# %%
condstr = cond2 & cond3 & cond4 & cond5 & cond6 & cond7 & cond8 & cond9

# %%
len(condstr)
# Out:
# 3288

# %%
t1dwistr = df.loc[[(condt1[i] and conddwi[i] and condstr[i]) for i in range(len(condt1))]  , :]
len(t1dwistr)
# Out:
# 458

# %%
t1dwi_str = df.loc[[(condt1[i] and not conddwi[i] and condstr[i]) for i in range(len(condt1))] , :]
len(t1dwi_str)
# Out:
# 1255

# %%
t1dwi_str_ = df.loc[[(condt1[i] and not conddwi[i] and not condstr[i]) for i in range(len(condt1))] , :]
len(t1dwi_str_)
# Out:
# 329

# %%
t1_dwi_str = df.loc[[(not condt1[i] and not conddwi[i] and condstr[i]) for i in range(len(condt1))] , :]
len(t1_dwi_str)
# Out:
# 107

# %%
t1dwistr_ = df.loc[[(condt1[i] and conddwi[i] and not condstr[i]) for i in range(len(condt1))] , :]
len(t1dwistr_)
# Out:
# 74

# %%
t1_dwistr_ = df.loc[[(not condt1[i] and conddwi[i] and not condstr[i]) for i in range(len(condt1))] , :]
len(t1_dwistr_)
# Out:
# 0

# %%
t1_dwistr = df.loc[[(not condt1[i] and conddwi[i] and condstr[i]) for i in range(len(condt1))] , :]
len(t1_dwistr)
# Out:
# 13

# %%
t1dwi_str_ = df.loc[[(condt1[i] and not conddwi[i] and not condstr[i]) for i in range(len(condt1))] , :]
len(t1dwi_str_)
# Out:
# 329

# %%
df = df.reset_index(drop=True)
df.head(20)
# Out:
#         SubjID  RID                        NONACCEL_T1_SCAN_FILENAME  \
# 0   002_S_0295  295  002_S_0295_20060418_A1_T1_1.5T_nonaccel_Preproc
# 1   002_S_0295  295  002_S_0295_20061102_A1_T1_1.5T_nonaccel_Preproc
# 2   002_S_0295  295  002_S_0295_20070525_A1_T1_1.5T_nonaccel_Preproc
# 3   002_S_0295  295  002_S_0295_20080723_A1_T1_1.5T_nonaccel_Preproc
# 4   002_S_0295  295  002_S_0295_20090522_A1_T1_1.5T_nonaccel_Preproc
# 5   002_S_0295  295  002_S_0295_20100513_A1_T1_1.5T_nonaccel_Preproc
# 6   002_S_0295  295    002_S_0295_20110602_A2_T1_3T_nonaccel_Preproc
# 7   002_S_0295  295    002_S_0295_20120510_A2_T1_3T_nonaccel_Preproc
# 8   002_S_0413  413                                              NaN
# 9   002_S_0413  413    002_S_0413_20150609_A2_T1_3T_nonaccel_Preproc
# 10  002_S_0413  413    002_S_0413_20140501_A2_T1_3T_nonaccel_Preproc
# 11  002_S_0413  413    002_S_0413_20130510_A2_T1_3T_nonaccel_Preproc
# 12  002_S_0413  413    002_S_0413_20120515_A2_T1_3T_nonaccel_Preproc
# 13  002_S_0413  413    002_S_0413_20110616_A2_T1_3T_nonaccel_Preproc
# 14  002_S_0413  413                                              NaN
# 15  002_S_0413  413  002_S_0413_20090504_A1_T1_1.5T_nonaccel_Preproc
# 16  002_S_0413  413  002_S_0413_20080731_A1_T1_1.5T_nonaccel_Preproc
# 17  002_S_0413  413  002_S_0413_20070601_A1_T1_1.5T_nonaccel_Preproc
# 18  002_S_0413  413  002_S_0413_20061115_A1_T1_1.5T_nonaccel_Preproc
# 19  002_S_0413  413  002_S_0413_20100506_A1_T1_1.5T_nonaccel_Preproc
#
#     NONACCEL_T1_IMAGEID                         NONACCEL_Path to RAW nifti  \
# 0               45108.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 1               40966.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 2               64025.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 3              123685.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 4              150177.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 5              291869.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 6              241350.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 7              308078.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 8                   NaN                                                NaN
# 9              649030.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 10             424741.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 11             373133.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 12             312701.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 13             242895.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 14                  NaN                                                NaN
# 15             149740.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 16             120917.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 17              60008.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 18              79122.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 19             291873.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
#
#    NONACCEL_Preprocessed for DL?  \
# 0                            yes
# 1                            yes
# 2                            yes
# 3                            yes
# 4                            yes
# 5                            yes
# 6                            yes
# 7                            yes
# 8                            NaN
# 9                            yes
# 10                           yes
# 11                           yes
# 12                           yes
# 13                           yes
# 14                           NaN
# 15                           yes
# 16                           yes
# 17                           yes
# 18                           yes
# 19                           yes
#
#                               NONACCEL_DL_6DOF_2MM_T1  \
# 0   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 1   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 2   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 3   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 4   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 5   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 6   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 7   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 8                                                 NaN
# 9   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 10  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 11  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 12  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 13  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 14                                                NaN
# 15  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 16  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 17  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 18  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 19  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
#
#                             NONACCEL_DL_6DOF_2MM_MASK  \
# 0   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 1   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 2   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 3   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 4   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 5   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 6   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 7   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 8                                                 NaN
# 9   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 10  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 11  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 12  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 13  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 14                                                NaN
# 15  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 16  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 17  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 18  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 19  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
#
#                               NONACCEL_DL_6DOF_2MM_GM  \
# 0   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 1   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 2   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 3   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 4   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 5   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 6   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 7   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 8                                                 NaN
# 9   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 10  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 11  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 12  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 13  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 14                                                NaN
# 15  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 16  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 17  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 18  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 19  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
#
#                               NONACCEL_DL_6DOF_2MM_WM  ...  \
# 0   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 1   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 2   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 3   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 4   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 5   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 6   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 7   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 8                                                 NaN  ...
# 9   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 10  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 11  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 12  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 13  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 14                                                NaN  ...
# 15  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 16  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 17  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 18  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 19  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
#
#              DWI_Matched_File_L1_Path_ENIGMATBSSspace  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#              DWI_Matched_File_MD_Path_ENIGMATBSSspace  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#              DWI_Matched_File_RD_Path_ENIGMATBSSspace  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                               T1_Path_ENIGMATBSSspace  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#          DWI_Matched_File_FA_Path_ENIGMATBSSspace_2MM  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#          DWI_Matched_File_L1_Path_ENIGMATBSSspace_2MM  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#          DWI_Matched_File_MD_Path_ENIGMATBSSspace_2MM  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#          DWI_Matched_File_RD_Path_ENIGMATBSSspace_2MM  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                           T1_Path_ENIGMATBSSspace_2MM  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#    DWI Preprocessing Pipeline (old=ADNI2 - new=ADNI3)
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                               ADNI3
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                              ADNI3
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
# [20 rows x 121 columns]

# %%
import nibabel as nib
from tensorflow import keras
from tensorflow.keras import layers
import random as pyrandom
import tensorflow_addons as tfa
from tensorflow.keras.preprocessing import image_dataset_from_directory

import nibabel as nib
from scipy import ndimage
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, precision_recall_curve, accuracy_score, f1_score, precision_score, recall_score, auc, roc_auc_score
from sklearn.utils import class_weight
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]= "6"

physical_devices = tf.config.list_physical_devices('GPU')
print("Num GPUs Available: ", len(physical_devices))
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# /lfs1/ashaji/condawork/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# Num GPUs Available:  1

# %%
### Hyperparameter config

init_lr = 1e-4
epochs = 50
early_stop = 7
seed = 53
drop_out = 0.5
weight_decay = 1e-4

batch_size=4
test_batch_size=4

# %%
def getCNN(width = 91,height = 109, depth = 91):
    
    def conv_block(inp,filt,name):
        inp = tf.keras.layers.Conv3D(filt,3,strides=1,padding='same')(inp)
        inp = tfa.layers.InstanceNormalization(center=False,scale=False)(inp)
        inp = tf.keras.layers.MaxPooling3D(2,strides=2,padding = 'valid')(inp)
        inp = tf.nn.relu(inp)
        return inp
    
    img0 = tf.keras.Input((91,109,91,1),name='inp0')
    inp0 = conv_block(img0,32,'conv_block1')
    inp0 = conv_block(inp0,64,'conv_block2')
    inp0 = conv_block(inp0,128,'conv_block3')
    inp0 = conv_block(inp0,256,'conv_block4')
    inp0 = conv_block(inp0,256,'conv_block5')
    
    ##LAST LAYER
    
    inp0 = tf.keras.layers.Conv3D(64,1,strides=1,padding='same')(inp0)
    inp0 = tfa.layers.InstanceNormalization(center=False,scale=False)(inp0)
    inp0 = tf.nn.relu(inp0)
    inp0 = tf.keras.layers.AveragePooling3D(2,2,'valid')(inp0)
    
    inp0 = tf.keras.layers.Dropout(rate=0.5,name='drop')(inp0)
    
    out0 = tf.keras.layers.Conv3D(1,1,strides=1,name='regconv1')(inp0)
    out0 = tf.keras.layers.Flatten(name='flatten1')(out0)
    out0 = tf.keras.layers.Dense(units=1,name='age1')(out0)
    
    model = keras.Model(img0,out0,name='3DCNN_Metis_T1')
    return model

model = getCNN()
model.summary()
# Out:
# 2023-12-25 10:08:33.666946: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10534 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:0e:00.0, compute capability: 6.1
# Model: "3DCNN_Metis_T1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inp0 (InputLayer)           [(None, 91, 109, 91, 1)]  0
#
#  conv3d (Conv3D)             (None, 91, 109, 91, 32)   896
#
#  instance_normalization (Ins  (None, 91, 109, 91, 32)  0
#  tanceNormalization)
#
#  max_pooling3d (MaxPooling3D  (None, 45, 54, 45, 32)   0
#  )
#
#  tf.nn.relu (TFOpLambda)     (None, 45, 54, 45, 32)    0
#
#  conv3d_1 (Conv3D)           (None, 45, 54, 45, 64)    55360
#
#  instance_normalization_1 (I  (None, 45, 54, 45, 64)   0
#  nstanceNormalization)
#
#  max_pooling3d_1 (MaxPooling  (None, 22, 27, 22, 64)   0
#  3D)
#
#  tf.nn.relu_1 (TFOpLambda)   (None, 22, 27, 22, 64)    0
#
#  conv3d_2 (Conv3D)           (None, 22, 27, 22, 128)   221312
#
#  instance_normalization_2 (I  (None, 22, 27, 22, 128)  0
#  nstanceNormalization)
#
#  max_pooling3d_2 (MaxPooling  (None, 11, 13, 11, 128)  0
#  3D)
#
#  tf.nn.relu_2 (TFOpLambda)   (None, 11, 13, 11, 128)   0
#
#  conv3d_3 (Conv3D)           (None, 11, 13, 11, 256)   884992
#
#  instance_normalization_3 (I  (None, 11, 13, 11, 256)  0
#  nstanceNormalization)
#
#  max_pooling3d_3 (MaxPooling  (None, 5, 6, 5, 256)     0
#  3D)
#
#  tf.nn.relu_3 (TFOpLambda)   (None, 5, 6, 5, 256)      0
#
#  conv3d_4 (Conv3D)           (None, 5, 6, 5, 256)      1769728
#
#  instance_normalization_4 (I  (None, 5, 6, 5, 256)     0
#  nstanceNormalization)
#
#  max_pooling3d_4 (MaxPooling  (None, 2, 3, 2, 256)     0
#  3D)
#
#  tf.nn.relu_4 (TFOpLambda)   (None, 2, 3, 2, 256)      0
#
#  conv3d_5 (Conv3D)           (None, 2, 3, 2, 64)       16448
#
#  instance_normalization_5 (I  (None, 2, 3, 2, 64)      0
#  nstanceNormalization)
#
#  tf.nn.relu_5 (TFOpLambda)   (None, 2, 3, 2, 64)       0
#
#  average_pooling3d (AverageP  (None, 1, 1, 1, 64)      0
#  ooling3D)
#
#  drop (Dropout)              (None, 1, 1, 1, 64)       0
#
#  regconv1 (Conv3D)           (None, 1, 1, 1, 1)        65
#
#  flatten1 (Flatten)          (None, 1)                 0
#
#  age1 (Dense)                (None, 1)                 2
#
# =================================================================
# Total params: 2,948,803
# Trainable params: 2,948,803
# Non-trainable params: 0
# _________________________________________________________________

# %%
len(t1dwistr)
# Out:
# 458

# %%
dwi = df.loc[conddwi,:]

# %%
len(dwi)
# Out:
# 545

# %%
train = dwi.drop(t1dwistr.index)

# %%
len(train)
# Out:
# 87

# %%
p = (np.ceil(0.7*len(t1dwistr))-1).astype(int)
q = (np.ceil(0.9*len(t1dwistr))-2).astype(int)
r = len(t1dwistr)
trainn = p
valn  = r - q
testn   = q - p
trainn, testn, valn
trainall = t1dwistr[:p]
testall  = t1dwistr[p:q]
valall   = t1dwistr[q:]
len(trainall), len(testall), len(valall)
# Out:
# (320, 91, 47)

# %%
datamix = [train,trainall,valall]
alltrain = pd.concat(datamix)
alltrain = alltrain.sort_values(by = ['SubjID'])

# %%
p = (np.ceil(0.8*len(alltrain))-1).astype(int)
p, len(alltrain)-p, 
# p = p - 2
# Out:
# (363, 91)

# %%
trainn = alltrain[:p]
valn   = alltrain[p:]
len(trainn),len(valn)
# Out:
# (363, 91)

# %%
for i in trainn['SubjID']:
    for j in valn['SubjID']:
        if i == j:
            print(i)

# %%
def checkTestAll(testall = testall):
    file = open('/lfs1/ashaji/Imputation_Problem/organized/DST/tester.txt','r')
    x = ''
    for i in testall['SubjID']:
        x += str(i+'\n')
    print(x==file.read())
checkTestAll()
# Out:
# True

# %%
class DataGenerator(tf.keras.utils.Sequence):
    def rotate(self,vol):
        def scipy_rotate(vol):
            angles = [-20,-10,-5,5,10,20]
            angle = pyrandom.choice(angles)
            vol = ndimage.rotate(vol,angle,reshape=False)
            vol[vol<0] = 0
            vol[vol>1] = 1
            return vol
        aug_vol = tf.numpy_function(scipy_rotate,[vol],tf.float32)
        return aug_vol

    def preprocessing(self,vol):
        vol1 = self.rotate(vol)
        vol1 = tf.expand_dims(vol1,axis=3)
        return vol1
    
    def read_scan(self,path):
        scan = nib.load(path)
        volume = scan.get_fdata()
        min = np.amax(volume)
        max = np.amin(volume)
        volume = (volume - min) / (max - min)
        volume = volume.astype("float32")
        return volume

    def __init__(self, data, batch_size, sample_weights=None):
        self.data = data
        self.batch_size = batch_size
        self.sample_weights = sample_weights

    def __len__(self):
        return (np.ceil(len(self.data) / float(self.batch_size))).astype(np.int)

    def __getitem__(self, idx):
        dwi  = self.data['DWI_Matched_File_FA_Path_ENIGMATBSSspace_2MM'].tolist()
        labels = self.data['AGE_at_scan'].astype(np.float32)
        
        batch_dwi = dwi[idx * self.batch_size: (idx + 1) * self.batch_size]
        batch_y = labels[idx * self.batch_size: (idx + 1) * self.batch_size]
     
        dwi_imgs = np.asarray([self.preprocessing(self.read_scan(path)) for path in batch_dwi])
        
        return (dwi_imgs, np.array(batch_y))
    
    def on_epoch_end(self):
        self.data = self.data.sample(frac=1)

# %%
dg_train = DataGenerator(trainn,batch_size)
dg_val = DataGenerator(valn,batch_size)
dg_testall = DataGenerator(testall,batch_size)

# %%
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    1e-2,decay_steps=1000,decay_rate=0.96,staircase=True
)
model.compile(
    loss='mse',
    optimizer = keras.optimizers.Adam(learning_rate=lr_schedule),
    metrics = [tf.keras.metrics.RootMeanSquaredError(name='rmse'),tf.keras.metrics.MeanAbsoluteError(name='mae')]   
)
early = keras.callbacks.EarlyStopping(monitor='val_loss',patience = 20, verbose = 1, restore_best_weights = True)

history = model.fit(
    dg_train,
    validation_data = dg_val,
    epochs = 200,
    verbose = 1,
    callbacks = [early]
)

model.save('/lfs1/ashaji/Imputation_Problem/further/DWI/modelonlyDWI')
# Out:
# /tmp/ipykernel_2343/994158989.py:33: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return (np.ceil(len(self.data) / float(self.batch_size))).astype(np.int)
# Epoch 1/200
# 2023-12-02 13:58:53.419910: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2023-12-02 13:58:56.884725: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-12-02 13:58:57.873709: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7fd06809d640 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-02 13:58:57.873814: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# 2023-12-02 13:58:57.884490: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-12-02 13:58:58.208381: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 91/91 [==============================] - ETA: 0s - loss: 2047.9354 - rmse: 45.2541 - mae: 40.7726
# 2023-12-02 14:00:21.445607: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 91/91 [==============================] - 108s 1s/step - loss: 2047.9354 - rmse: 45.2541 - mae: 40.7726 - val_loss: 128.2068 - val_rmse: 11.3228 - val_mae: 9.5928
# Epoch 2/200
# 91/91 [==============================] - 84s 922ms/step - loss: 187.3144 - rmse: 13.6863 - mae: 10.9743 - val_loss: 44.2653 - val_rmse: 6.6532 - val_mae: 5.5657
# Epoch 3/200
# 91/91 [==============================] - 86s 939ms/step - loss: 169.1828 - rmse: 13.0070 - mae: 10.4975 - val_loss: 42.5644 - val_rmse: 6.5241 - val_mae: 5.3828
# Epoch 4/200
# 91/91 [==============================] - 86s 945ms/step - loss: 188.4326 - rmse: 13.7271 - mae: 10.9439 - val_loss: 42.8896 - val_rmse: 6.5490 - val_mae: 5.4314
# Epoch 5/200
# 91/91 [==============================] - 84s 924ms/step - loss: 178.4988 - rmse: 13.3603 - mae: 10.7635 - val_loss: 48.6571 - val_rmse: 6.9755 - val_mae: 5.8773
# Epoch 6/200
# 91/91 [==============================] - 85s 933ms/step - loss: 152.2889 - rmse: 12.3405 - mae: 9.9371 - val_loss: 51.8710 - val_rmse: 7.2021 - val_mae: 5.4933
# Epoch 7/200
# 91/91 [==============================] - 84s 928ms/step - loss: 187.3421 - rmse: 13.6873 - mae: 11.0597 - val_loss: 48.8975 - val_rmse: 6.9927 - val_mae: 5.5360
# Epoch 8/200
# 91/91 [==============================] - 84s 927ms/step - loss: 151.4760 - rmse: 12.3076 - mae: 9.7982 - val_loss: 45.5884 - val_rmse: 6.7519 - val_mae: 5.6787
# Epoch 9/200
# 91/91 [==============================] - 84s 928ms/step - loss: 168.1413 - rmse: 12.9669 - mae: 10.2200 - val_loss: 40.8296 - val_rmse: 6.3898 - val_mae: 5.1968
# Epoch 10/200
# 91/91 [==============================] - 84s 918ms/step - loss: 176.7915 - rmse: 13.2963 - mae: 10.8507 - val_loss: 42.3106 - val_rmse: 6.5047 - val_mae: 5.3701
# Epoch 11/200
# 91/91 [==============================] - 84s 921ms/step - loss: 170.0181 - rmse: 13.0391 - mae: 10.5024 - val_loss: 44.7218 - val_rmse: 6.6874 - val_mae: 5.6136
# Epoch 12/200
# 91/91 [==============================] - 84s 926ms/step - loss: 153.0302 - rmse: 12.3705 - mae: 9.8356 - val_loss: 50.0955 - val_rmse: 7.0778 - val_mae: 5.4447
# Epoch 13/200
# 91/91 [==============================] - 84s 920ms/step - loss: 156.5572 - rmse: 12.5123 - mae: 10.0251 - val_loss: 47.5958 - val_rmse: 6.8990 - val_mae: 5.7811
# Epoch 14/200
# 91/91 [==============================] - 85s 928ms/step - loss: 128.9974 - rmse: 11.3577 - mae: 9.0713 - val_loss: 46.9433 - val_rmse: 6.8515 - val_mae: 5.7147
# Epoch 15/200
# 91/91 [==============================] - 85s 935ms/step - loss: 145.0641 - rmse: 12.0443 - mae: 9.7308 - val_loss: 45.9107 - val_rmse: 6.7757 - val_mae: 5.7314
# Epoch 16/200
# 91/91 [==============================] - 85s 937ms/step - loss: 129.6662 - rmse: 11.3871 - mae: 8.8635 - val_loss: 46.0219 - val_rmse: 6.7839 - val_mae: 5.7024
# Epoch 17/200
# 91/91 [==============================] - 85s 933ms/step - loss: 137.3787 - rmse: 11.7209 - mae: 9.1240 - val_loss: 42.5472 - val_rmse: 6.5228 - val_mae: 5.1189
# Epoch 18/200
# 91/91 [==============================] - 86s 939ms/step - loss: 128.1494 - rmse: 11.3203 - mae: 8.7849 - val_loss: 48.8884 - val_rmse: 6.9920 - val_mae: 5.4465
# Epoch 19/200
# 91/91 [==============================] - 86s 941ms/step - loss: 123.2906 - rmse: 11.1036 - mae: 8.7586 - val_loss: 41.8856 - val_rmse: 6.4719 - val_mae: 5.1740
# Epoch 20/200
# 91/91 [==============================] - 85s 939ms/step - loss: 137.0936 - rmse: 11.7087 - mae: 9.3590 - val_loss: 41.7452 - val_rmse: 6.4611 - val_mae: 5.0705
# Epoch 21/200
# 91/91 [==============================] - 86s 949ms/step - loss: 131.3169 - rmse: 11.4594 - mae: 8.9837 - val_loss: 39.0691 - val_rmse: 6.2505 - val_mae: 5.1574
# Epoch 22/200
# 91/91 [==============================] - 84s 924ms/step - loss: 127.4181 - rmse: 11.2880 - mae: 9.2958 - val_loss: 52.9776 - val_rmse: 7.2786 - val_mae: 5.7252
# Epoch 23/200
# 91/91 [==============================] - 86s 941ms/step - loss: 124.9723 - rmse: 11.1791 - mae: 8.8077 - val_loss: 40.2626 - val_rmse: 6.3453 - val_mae: 4.9274
# Epoch 24/200
# 91/91 [==============================] - 86s 945ms/step - loss: 131.2522 - rmse: 11.4565 - mae: 9.2444 - val_loss: 44.3752 - val_rmse: 6.6615 - val_mae: 5.4340
# Epoch 25/200
# 91/91 [==============================] - 87s 959ms/step - loss: 127.4467 - rmse: 11.2892 - mae: 9.0111 - val_loss: 39.6422 - val_rmse: 6.2962 - val_mae: 5.0904
# Epoch 26/200
# 91/91 [==============================] - 86s 944ms/step - loss: 122.6381 - rmse: 11.0742 - mae: 8.8656 - val_loss: 35.5435 - val_rmse: 5.9618 - val_mae: 4.7028
# Epoch 27/200
# 91/91 [==============================] - 88s 964ms/step - loss: 126.7181 - rmse: 11.2569 - mae: 8.9882 - val_loss: 36.4877 - val_rmse: 6.0405 - val_mae: 4.6941
# Epoch 28/200
# 91/91 [==============================] - 83s 906ms/step - loss: 119.7187 - rmse: 10.9416 - mae: 8.6639 - val_loss: 42.0526 - val_rmse: 6.4848 - val_mae: 5.0681
# Epoch 29/200
# 91/91 [==============================] - 85s 937ms/step - loss: 111.8932 - rmse: 10.5780 - mae: 8.4883 - val_loss: 43.5381 - val_rmse: 6.5983 - val_mae: 5.4517
# Epoch 30/200
# 91/91 [==============================] - 83s 916ms/step - loss: 113.5580 - rmse: 10.6564 - mae: 8.7013 - val_loss: 38.3825 - val_rmse: 6.1954 - val_mae: 5.0464
# Epoch 31/200
# 91/91 [==============================] - 85s 928ms/step - loss: 121.0090 - rmse: 11.0004 - mae: 8.7966 - val_loss: 34.8540 - val_rmse: 5.9037 - val_mae: 4.6720
# Epoch 32/200
# 91/91 [==============================] - 87s 954ms/step - loss: 107.0278 - rmse: 10.3454 - mae: 8.1399 - val_loss: 50.6411 - val_rmse: 7.1163 - val_mae: 5.6649
# Epoch 33/200
# 91/91 [==============================] - 88s 965ms/step - loss: 125.0205 - rmse: 11.1813 - mae: 8.9921 - val_loss: 34.0683 - val_rmse: 5.8368 - val_mae: 4.5692
# Epoch 34/200
# 91/91 [==============================] - 83s 917ms/step - loss: 116.0685 - rmse: 10.7735 - mae: 8.4505 - val_loss: 33.8674 - val_rmse: 5.8196 - val_mae: 4.4260
# Epoch 35/200
# 91/91 [==============================] - 86s 939ms/step - loss: 115.2182 - rmse: 10.7340 - mae: 8.5026 - val_loss: 33.2679 - val_rmse: 5.7678 - val_mae: 4.5047
# Epoch 36/200
# 91/91 [==============================] - 88s 964ms/step - loss: 107.3581 - rmse: 10.3614 - mae: 8.2214 - val_loss: 32.8571 - val_rmse: 5.7321 - val_mae: 4.5249
# Epoch 37/200
# 91/91 [==============================] - 84s 919ms/step - loss: 106.8450 - rmse: 10.3366 - mae: 8.2991 - val_loss: 33.1072 - val_rmse: 5.7539 - val_mae: 4.4963
# Epoch 38/200
# 91/91 [==============================] - 84s 922ms/step - loss: 115.7606 - rmse: 10.7592 - mae: 8.6313 - val_loss: 30.7733 - val_rmse: 5.5474 - val_mae: 4.3091
# Epoch 39/200
# 91/91 [==============================] - 84s 922ms/step - loss: 93.7708 - rmse: 9.6835 - mae: 7.8828 - val_loss: 32.6905 - val_rmse: 5.7176 - val_mae: 4.4058
# Epoch 40/200
# 91/91 [==============================] - 89s 974ms/step - loss: 113.2392 - rmse: 10.6414 - mae: 8.7263 - val_loss: 32.2132 - val_rmse: 5.6757 - val_mae: 4.3180
# Epoch 41/200
# 91/91 [==============================] - 88s 966ms/step - loss: 109.5048 - rmse: 10.4645 - mae: 8.4851 - val_loss: 37.0420 - val_rmse: 6.0862 - val_mae: 4.6544
# Epoch 42/200
# 91/91 [==============================] - 84s 922ms/step - loss: 85.7067 - rmse: 9.2578 - mae: 7.2526 - val_loss: 38.6834 - val_rmse: 6.2196 - val_mae: 4.8422
# Epoch 43/200
# 91/91 [==============================] - 88s 974ms/step - loss: 80.0891 - rmse: 8.9493 - mae: 7.1963 - val_loss: 28.9252 - val_rmse: 5.3782 - val_mae: 4.0282
# Epoch 44/200
# 91/91 [==============================] - 85s 928ms/step - loss: 96.7636 - rmse: 9.8368 - mae: 7.7651 - val_loss: 33.4380 - val_rmse: 5.7826 - val_mae: 4.5056
# Epoch 45/200
# 91/91 [==============================] - 86s 949ms/step - loss: 88.6022 - rmse: 9.4129 - mae: 7.2926 - val_loss: 56.2082 - val_rmse: 7.4972 - val_mae: 6.2050
# Epoch 46/200
# 91/91 [==============================] - 83s 914ms/step - loss: 89.7419 - rmse: 9.4732 - mae: 7.5570 - val_loss: 35.0244 - val_rmse: 5.9181 - val_mae: 4.6740
# Epoch 47/200
# 91/91 [==============================] - 85s 934ms/step - loss: 80.1257 - rmse: 8.9513 - mae: 6.9488 - val_loss: 32.2980 - val_rmse: 5.6831 - val_mae: 4.5093
# Epoch 48/200
# 91/91 [==============================] - 84s 925ms/step - loss: 84.9082 - rmse: 9.2146 - mae: 7.2314 - val_loss: 33.0198 - val_rmse: 5.7463 - val_mae: 4.5381
# Epoch 49/200
# 91/91 [==============================] - 86s 944ms/step - loss: 81.4487 - rmse: 9.0249 - mae: 7.2313 - val_loss: 32.6615 - val_rmse: 5.7150 - val_mae: 4.4864
# Epoch 50/200
# 91/91 [==============================] - 83s 915ms/step - loss: 85.9274 - rmse: 9.2697 - mae: 7.2020 - val_loss: 30.8163 - val_rmse: 5.5512 - val_mae: 4.3629
# Epoch 51/200
# 91/91 [==============================] - 86s 942ms/step - loss: 86.5167 - rmse: 9.3014 - mae: 7.2616 - val_loss: 29.6080 - val_rmse: 5.4413 - val_mae: 4.3443
# Epoch 52/200
# 91/91 [==============================] - 82s 905ms/step - loss: 73.8695 - rmse: 8.5947 - mae: 6.9016 - val_loss: 28.1342 - val_rmse: 5.3042 - val_mae: 4.0670
# Epoch 53/200
# 91/91 [==============================] - 83s 911ms/step - loss: 89.9171 - rmse: 9.4825 - mae: 7.6807 - val_loss: 31.7293 - val_rmse: 5.6329 - val_mae: 4.3109
# Epoch 54/200
# 91/91 [==============================] - 84s 923ms/step - loss: 74.8547 - rmse: 8.6519 - mae: 6.9868 - val_loss: 30.4247 - val_rmse: 5.5159 - val_mae: 4.3597
# Epoch 55/200
# 91/91 [==============================] - 86s 942ms/step - loss: 85.9255 - rmse: 9.2696 - mae: 7.3109 - val_loss: 29.5637 - val_rmse: 5.4372 - val_mae: 4.1917
# Epoch 56/200
# 91/91 [==============================] - 84s 920ms/step - loss: 67.8720 - rmse: 8.2384 - mae: 6.4545 - val_loss: 29.2953 - val_rmse: 5.4125 - val_mae: 4.0827
# Epoch 57/200
# 91/91 [==============================] - 85s 933ms/step - loss: 76.8479 - rmse: 8.7663 - mae: 6.8880 - val_loss: 27.6357 - val_rmse: 5.2570 - val_mae: 4.0428
# Epoch 58/200
# 91/91 [==============================] - 84s 927ms/step - loss: 81.7915 - rmse: 9.0439 - mae: 7.1440 - val_loss: 40.4083 - val_rmse: 6.3568 - val_mae: 4.9694
# Epoch 59/200
# 91/91 [==============================] - 82s 896ms/step - loss: 79.6656 - rmse: 8.9256 - mae: 7.2012 - val_loss: 35.0881 - val_rmse: 5.9235 - val_mae: 4.6282
# Epoch 60/200
# 91/91 [==============================] - 85s 929ms/step - loss: 69.7334 - rmse: 8.3507 - mae: 6.4210 - val_loss: 27.6906 - val_rmse: 5.2622 - val_mae: 4.1157
# Epoch 61/200
# 91/91 [==============================] - 85s 936ms/step - loss: 72.4708 - rmse: 8.5130 - mae: 6.8526 - val_loss: 28.0857 - val_rmse: 5.2996 - val_mae: 4.0646
# Epoch 62/200
# 91/91 [==============================] - 85s 931ms/step - loss: 69.9021 - rmse: 8.3607 - mae: 6.7242 - val_loss: 28.3767 - val_rmse: 5.3270 - val_mae: 4.1138
# Epoch 63/200
# 91/91 [==============================] - 86s 942ms/step - loss: 70.9332 - rmse: 8.4222 - mae: 6.7182 - val_loss: 27.7011 - val_rmse: 5.2632 - val_mae: 3.9164
# Epoch 64/200
# 91/91 [==============================] - 85s 939ms/step - loss: 67.5695 - rmse: 8.2201 - mae: 6.7025 - val_loss: 27.0547 - val_rmse: 5.2014 - val_mae: 3.9756
# Epoch 65/200
# 91/91 [==============================] - 84s 927ms/step - loss: 67.2068 - rmse: 8.1980 - mae: 6.5209 - val_loss: 28.6620 - val_rmse: 5.3537 - val_mae: 4.0999
# Epoch 66/200
# 91/91 [==============================] - 87s 951ms/step - loss: 63.4166 - rmse: 7.9635 - mae: 6.3642 - val_loss: 26.4272 - val_rmse: 5.1407 - val_mae: 3.9475
# Epoch 67/200
# 91/91 [==============================] - 84s 921ms/step - loss: 58.4623 - rmse: 7.6461 - mae: 6.1645 - val_loss: 30.6434 - val_rmse: 5.5356 - val_mae: 4.2595
# Epoch 68/200
# 91/91 [==============================] - 87s 954ms/step - loss: 54.2700 - rmse: 7.3668 - mae: 5.7549 - val_loss: 31.5217 - val_rmse: 5.6144 - val_mae: 4.3725
# Epoch 69/200
# 91/91 [==============================] - 86s 945ms/step - loss: 50.6095 - rmse: 7.1140 - mae: 5.7193 - val_loss: 26.6434 - val_rmse: 5.1617 - val_mae: 4.0253
# Epoch 70/200
# 91/91 [==============================] - 86s 949ms/step - loss: 60.5568 - rmse: 7.7818 - mae: 6.2373 - val_loss: 42.1614 - val_rmse: 6.4932 - val_mae: 5.0846
# Epoch 71/200
# 91/91 [==============================] - 86s 944ms/step - loss: 57.2946 - rmse: 7.5693 - mae: 5.8932 - val_loss: 36.3613 - val_rmse: 6.0300 - val_mae: 4.8059
# Epoch 72/200
# 91/91 [==============================] - 87s 958ms/step - loss: 54.6101 - rmse: 7.3899 - mae: 5.9250 - val_loss: 31.3138 - val_rmse: 5.5959 - val_mae: 4.2853
# Epoch 73/200
# 91/91 [==============================] - 85s 930ms/step - loss: 50.4068 - rmse: 7.0998 - mae: 5.6383 - val_loss: 38.6023 - val_rmse: 6.2131 - val_mae: 4.8893
# Epoch 74/200
# 91/91 [==============================] - 85s 935ms/step - loss: 53.4512 - rmse: 7.3110 - mae: 5.8354 - val_loss: 29.0736 - val_rmse: 5.3920 - val_mae: 4.1546
# Epoch 75/200
# 91/91 [==============================] - 87s 951ms/step - loss: 55.9110 - rmse: 7.4774 - mae: 5.8369 - val_loss: 24.3705 - val_rmse: 4.9366 - val_mae: 3.8306
# Epoch 76/200
# 91/91 [==============================] - 84s 922ms/step - loss: 49.1672 - rmse: 7.0119 - mae: 5.5779 - val_loss: 35.9435 - val_rmse: 5.9953 - val_mae: 4.7591
# Epoch 77/200
# 91/91 [==============================] - 83s 915ms/step - loss: 51.2239 - rmse: 7.1571 - mae: 5.5355 - val_loss: 27.8816 - val_rmse: 5.2803 - val_mae: 4.0045
# Epoch 78/200
# 91/91 [==============================] - 86s 947ms/step - loss: 46.6660 - rmse: 6.8313 - mae: 5.4392 - val_loss: 25.6511 - val_rmse: 5.0647 - val_mae: 3.8677
# Epoch 79/200
# 91/91 [==============================] - 85s 933ms/step - loss: 49.1411 - rmse: 7.0101 - mae: 5.4751 - val_loss: 27.4993 - val_rmse: 5.2440 - val_mae: 4.0766
# Epoch 80/200
# 91/91 [==============================] - 85s 939ms/step - loss: 52.5236 - rmse: 7.2473 - mae: 5.7648 - val_loss: 29.3816 - val_rmse: 5.4205 - val_mae: 4.3947
# Epoch 81/200
# 91/91 [==============================] - 84s 924ms/step - loss: 40.5052 - rmse: 6.3644 - mae: 5.1530 - val_loss: 30.3534 - val_rmse: 5.5094 - val_mae: 4.3496
# Epoch 82/200
# 91/91 [==============================] - 87s 957ms/step - loss: 49.0576 - rmse: 7.0041 - mae: 5.6024 - val_loss: 40.8576 - val_rmse: 6.3920 - val_mae: 5.0581
# Epoch 83/200
# 91/91 [==============================] - 84s 921ms/step - loss: 43.8323 - rmse: 6.6206 - mae: 5.3560 - val_loss: 30.2137 - val_rmse: 5.4967 - val_mae: 4.3031
# Epoch 84/200
# 91/91 [==============================] - 85s 929ms/step - loss: 42.0804 - rmse: 6.4869 - mae: 5.2486 - val_loss: 26.1940 - val_rmse: 5.1180 - val_mae: 3.9980
# Epoch 85/200
# 91/91 [==============================] - 86s 940ms/step - loss: 44.2847 - rmse: 6.6547 - mae: 5.3862 - val_loss: 27.1606 - val_rmse: 5.2116 - val_mae: 4.2639
# Epoch 86/200
# 91/91 [==============================] - 84s 922ms/step - loss: 38.6911 - rmse: 6.2202 - mae: 5.0453 - val_loss: 29.6997 - val_rmse: 5.4497 - val_mae: 4.5161
# Epoch 87/200
# 91/91 [==============================] - 85s 938ms/step - loss: 33.8815 - rmse: 5.8208 - mae: 4.6040 - val_loss: 34.8519 - val_rmse: 5.9035 - val_mae: 4.6334
# Epoch 88/200
# 91/91 [==============================] - 86s 948ms/step - loss: 39.7925 - rmse: 6.3081 - mae: 5.0547 - val_loss: 25.3605 - val_rmse: 5.0359 - val_mae: 3.9927
# Epoch 89/200
# 91/91 [==============================] - 83s 911ms/step - loss: 38.2163 - rmse: 6.1819 - mae: 4.9876 - val_loss: 35.1926 - val_rmse: 5.9323 - val_mae: 4.6217
# Epoch 90/200
# 91/91 [==============================] - 85s 929ms/step - loss: 38.4511 - rmse: 6.2009 - mae: 4.9353 - val_loss: 29.5649 - val_rmse: 5.4374 - val_mae: 4.2875
# Epoch 91/200
# 91/91 [==============================] - 86s 948ms/step - loss: 37.9682 - rmse: 6.1618 - mae: 5.0018 - val_loss: 31.3537 - val_rmse: 5.5994 - val_mae: 4.3471
# Epoch 92/200
# 91/91 [==============================] - 84s 918ms/step - loss: 31.2013 - rmse: 5.5858 - mae: 4.4509 - val_loss: 40.7080 - val_rmse: 6.3803 - val_mae: 5.0999
# Epoch 93/200
# 91/91 [==============================] - 85s 937ms/step - loss: 33.2994 - rmse: 5.7706 - mae: 4.5567 - val_loss: 29.5746 - val_rmse: 5.4383 - val_mae: 4.2768
# Epoch 94/200
# 91/91 [==============================] - 83s 917ms/step - loss: 31.5863 - rmse: 5.6202 - mae: 4.3585 - val_loss: 24.4671 - val_rmse: 4.9464 - val_mae: 3.9662
# Epoch 95/200
# 91/91 [==============================] - ETA: 0s - loss: 32.0078 - rmse: 5.6575 - mae: 4.5775Restoring model weights from the end of the best epoch: 75.
# 91/91 [==============================] - 85s 933ms/step - loss: 32.0078 - rmse: 5.6575 - mae: 4.5775 - val_loss: 30.1670 - val_rmse: 5.4925 - val_mae: 4.3927
# Epoch 95: early stopping
# 2023-12-02 16:13:58.789511: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,1,1,64]
# 	 [[{{node inputs}}]]
# 2023-12-02 16:13:59.773286: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,1,1,64]
# 	 [[{{node inputs}}]]
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 7). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lfs1/ashaji/Imputation_Problem/further/DWI/modelonlyDWI/assets
# INFO:tensorflow:Assets written to: /lfs1/ashaji/Imputation_Problem/further/DWI/modelonlyDWI/assets

# %%
model.evaluate(dg_testall)
# Out:
# /tmp/ipykernel_2343/994158989.py:33: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return (np.ceil(len(self.data) / float(self.batch_size))).astype(np.int)
# 2023-12-04 02:10:45.753136: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 23/23 [==============================] - 27s 1s/step - loss: 33.6804 - rmse: 5.8035 - mae: 4.4652
# [33.68040466308594, 5.8034820556640625, 4.46523904800415]
