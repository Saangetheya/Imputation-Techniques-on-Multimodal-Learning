# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import os
# Out:
# 2023-12-24 10:42:51.510189: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-24 10:42:52.415377: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def checkfilepath(filepath):
    return os.path.exists(filepath)

# %%
df = pd.read_excel('/lfs1/ashaji/Imputation_Problem/data/ADNI_final.xlsx', engine='openpyxl')
df['SubjID'].replace('',np.nan,inplace=True)
df['AGE_at_scan'].replace('',np.nan,inplace=True)
df.dropna(subset=['SubjID','AGE_at_scan'], inplace=True)
df = df.reset_index(drop=True)
df.loc[df['SEX']=='M','SEX'] = 1
df.loc[df['SEX']=='F','SEX'] = 0
condCN = df['DX'] == 'CN'
df = df.sort_values(by = ['SubjID'])
df = df.loc[condCN,:]
# df = df.sample(frac = 1)
df = df.reset_index(drop=True)

# %%
df['SEX'].replace('',np.nan,inplace=True)
df['CDRSB'].replace('',np.nan,inplace=True)
df['ADAS11'].replace('',np.nan,inplace=True)
df['ADAS13'].replace('',np.nan,inplace=True)
df['MMSE'].replace('',np.nan,inplace=True)
df['MOCA'].replace('',np.nan,inplace=True)
df['APOE A1'].replace('',np.nan,inplace=True)
df['APOE A2'].replace('',np.nan,inplace=True)

# %%
cond = [checkfilepath(str(x)) for x in df['ACCEL_DL_6DOF_2MM_T1']]
cond0 = df['ACCEL_Preprocessed for DL?']=='yes'

# %%
conddwi = [checkfilepath(str(x)) for x in df['DWI_Matched_File_FA_Path_ENIGMATBSSspace_2MM']]

# %%
len(conddwi)
# Out:
# 3288

# %%
cond2 = df['SEX'].isnull()
cond2 = np.invert(cond2)
cond3 = df['CDRSB'].isnull()
cond3 = np.invert(cond3)
cond4 = df['ADAS11'].isnull()
cond4 = np.invert(cond4)
cond5 = df['ADAS13'].isnull()
cond5 = np.invert(cond5)
cond6 = df['MMSE'].isnull()
cond6 = np.invert(cond6)
cond7 = df['MOCA'].isnull()
cond7 = np.invert(cond7)
cond8 = df['APOE A1'].isnull()
cond8 = np.invert(cond8)
cond9 = df['APOE A2'].isnull()
cond9 = np.invert(cond9)

# %%
condt1 = [cond[i] & cond0[i]  for i in range(len(cond))]

# %%
condstr = cond2 & cond3 & cond4 & cond5 & cond6 & cond7 & cond8 & cond9

# %%
len(condstr)
# Out:
# 3288

# %%
t1dwistr = df.loc[[(condt1[i] and conddwi[i] and condstr[i]) for i in range(len(condt1))]  , :]
len(t1dwistr)
# Out:
# 458

# %%
t1dwi_str = df.loc[[(condt1[i] and not conddwi[i] and condstr[i]) for i in range(len(condt1))] , :]
len(t1dwi_str)
# Out:
# 1255

# %%
t1dwi_str_ = df.loc[[(condt1[i] and not conddwi[i] and not condstr[i]) for i in range(len(condt1))] , :]
len(t1dwi_str_)
# Out:
# 329

# %%
t1_dwi_str = df.loc[[(not condt1[i] and not conddwi[i] and condstr[i]) for i in range(len(condt1))] , :]
len(t1_dwi_str)
# Out:
# 107

# %%
t1dwistr_ = df.loc[[(condt1[i] and conddwi[i] and not condstr[i]) for i in range(len(condt1))] , :]
len(t1dwistr_)
# Out:
# 74

# %%
t1_dwistr_ = df.loc[[(not condt1[i] and conddwi[i] and not condstr[i]) for i in range(len(condt1))] , :]
len(t1_dwistr_)
# Out:
# 0

# %%
t1_dwistr = df.loc[[(not condt1[i] and conddwi[i] and condstr[i]) for i in range(len(condt1))] , :]
len(t1_dwistr)
# Out:
# 13

# %%
t1dwi_str_ = df.loc[[(condt1[i] and not conddwi[i] and not condstr[i]) for i in range(len(condt1))] , :]
len(t1dwi_str_)
# Out:
# 329

# %%
df = df.reset_index(drop=True)
df.head(20)
# Out:
#         SubjID  RID                        NONACCEL_T1_SCAN_FILENAME  \
# 0   002_S_0295  295  002_S_0295_20060418_A1_T1_1.5T_nonaccel_Preproc
# 1   002_S_0295  295  002_S_0295_20061102_A1_T1_1.5T_nonaccel_Preproc
# 2   002_S_0295  295  002_S_0295_20070525_A1_T1_1.5T_nonaccel_Preproc
# 3   002_S_0295  295  002_S_0295_20080723_A1_T1_1.5T_nonaccel_Preproc
# 4   002_S_0295  295  002_S_0295_20090522_A1_T1_1.5T_nonaccel_Preproc
# 5   002_S_0295  295  002_S_0295_20100513_A1_T1_1.5T_nonaccel_Preproc
# 6   002_S_0295  295    002_S_0295_20110602_A2_T1_3T_nonaccel_Preproc
# 7   002_S_0295  295    002_S_0295_20120510_A2_T1_3T_nonaccel_Preproc
# 8   002_S_0413  413                                              NaN
# 9   002_S_0413  413    002_S_0413_20150609_A2_T1_3T_nonaccel_Preproc
# 10  002_S_0413  413    002_S_0413_20140501_A2_T1_3T_nonaccel_Preproc
# 11  002_S_0413  413    002_S_0413_20130510_A2_T1_3T_nonaccel_Preproc
# 12  002_S_0413  413    002_S_0413_20120515_A2_T1_3T_nonaccel_Preproc
# 13  002_S_0413  413    002_S_0413_20110616_A2_T1_3T_nonaccel_Preproc
# 14  002_S_0413  413                                              NaN
# 15  002_S_0413  413  002_S_0413_20090504_A1_T1_1.5T_nonaccel_Preproc
# 16  002_S_0413  413  002_S_0413_20080731_A1_T1_1.5T_nonaccel_Preproc
# 17  002_S_0413  413  002_S_0413_20070601_A1_T1_1.5T_nonaccel_Preproc
# 18  002_S_0413  413  002_S_0413_20061115_A1_T1_1.5T_nonaccel_Preproc
# 19  002_S_0413  413  002_S_0413_20100506_A1_T1_1.5T_nonaccel_Preproc
#
#     NONACCEL_T1_IMAGEID                         NONACCEL_Path to RAW nifti  \
# 0               45108.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 1               40966.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 2               64025.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 3              123685.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 4              150177.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 5              291869.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 6              241350.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 7              308078.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 8                   NaN                                                NaN
# 9              649030.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 10             424741.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 11             373133.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 12             312701.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 13             242895.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 14                  NaN                                                NaN
# 15             149740.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 16             120917.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 17              60008.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 18              79122.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 19             291873.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
#
#    NONACCEL_Preprocessed for DL?  \
# 0                            yes
# 1                            yes
# 2                            yes
# 3                            yes
# 4                            yes
# 5                            yes
# 6                            yes
# 7                            yes
# 8                            NaN
# 9                            yes
# 10                           yes
# 11                           yes
# 12                           yes
# 13                           yes
# 14                           NaN
# 15                           yes
# 16                           yes
# 17                           yes
# 18                           yes
# 19                           yes
#
#                               NONACCEL_DL_6DOF_2MM_T1  \
# 0   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 1   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 2   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 3   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 4   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 5   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 6   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 7   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 8                                                 NaN
# 9   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 10  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 11  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 12  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 13  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 14                                                NaN
# 15  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 16  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 17  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 18  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 19  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
#
#                             NONACCEL_DL_6DOF_2MM_MASK  \
# 0   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 1   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 2   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 3   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 4   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 5   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 6   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 7   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 8                                                 NaN
# 9   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 10  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 11  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 12  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 13  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 14                                                NaN
# 15  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 16  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 17  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 18  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 19  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
#
#                               NONACCEL_DL_6DOF_2MM_GM  \
# 0   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 1   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 2   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 3   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 4   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 5   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 6   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 7   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 8                                                 NaN
# 9   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 10  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 11  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 12  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 13  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 14                                                NaN
# 15  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 16  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 17  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 18  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 19  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
#
#                               NONACCEL_DL_6DOF_2MM_WM  ...  \
# 0   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 1   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 2   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 3   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 4   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 5   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 6   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 7   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 8                                                 NaN  ...
# 9   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 10  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 11  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 12  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 13  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 14                                                NaN  ...
# 15  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 16  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 17  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 18  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 19  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
#
#              DWI_Matched_File_L1_Path_ENIGMATBSSspace  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#              DWI_Matched_File_MD_Path_ENIGMATBSSspace  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#              DWI_Matched_File_RD_Path_ENIGMATBSSspace  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                               T1_Path_ENIGMATBSSspace  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#          DWI_Matched_File_FA_Path_ENIGMATBSSspace_2MM  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#          DWI_Matched_File_L1_Path_ENIGMATBSSspace_2MM  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#          DWI_Matched_File_MD_Path_ENIGMATBSSspace_2MM  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#          DWI_Matched_File_RD_Path_ENIGMATBSSspace_2MM  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                           T1_Path_ENIGMATBSSspace_2MM  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#    DWI Preprocessing Pipeline (old=ADNI2 - new=ADNI3)
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                               ADNI3
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                              ADNI3
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
# [20 rows x 121 columns]

# %%
import nibabel as nib
from tensorflow import keras
from tensorflow.keras import layers
import random as pyrandom
import tensorflow_addons as tfa
from tensorflow.keras.preprocessing import image_dataset_from_directory

import nibabel as nib
from scipy import ndimage
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, precision_recall_curve, accuracy_score, f1_score, precision_score, recall_score, auc, roc_auc_score
from sklearn.utils import class_weight
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]= "6"

physical_devices = tf.config.list_physical_devices('GPU')
print("Num GPUs Available: ", len(physical_devices))
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# /lfs1/ashaji/condawork/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# Num GPUs Available:  1

# %%
### Hyperparameter config

init_lr = 1e-4
epochs = 50
early_stop = 7
seed = 53
drop_out = 0.5
weight_decay = 1e-4

batch_size=4
test_batch_size=4

# %%
def getCNN(width = 91,height = 109, depth = 91):
    
    def conv_block(inp,filt,name):
        inp = tf.keras.layers.Conv3D(filt,3,strides=1,padding='same')(inp)
        inp = tfa.layers.InstanceNormalization(center=False,scale=False)(inp)
        inp = tf.keras.layers.MaxPooling3D(2,strides=2,padding = 'valid')(inp)
        inp = tf.nn.relu(inp)
        return inp
    
    img0 = tf.keras.Input((91,109,91,1),name='inp0')
    inp0 = conv_block(img0,32,'conv_block1')
    inp0 = conv_block(inp0,64,'conv_block2')
    inp0 = conv_block(inp0,128,'conv_block3')
    inp0 = conv_block(inp0,256,'conv_block4')
    inp0 = conv_block(inp0,256,'conv_block5')
    
    ##LAST LAYER
    
    inp0 = tf.keras.layers.Conv3D(64,1,strides=1,padding='same')(inp0)
    inp0 = tfa.layers.InstanceNormalization(center=False,scale=False)(inp0)
    inp0 = tf.nn.relu(inp0)
    inp0 = tf.keras.layers.AveragePooling3D(2,2,'valid')(inp0)
    
    inp0 = tf.keras.layers.Dropout(rate=0.5,name='drop')(inp0)
    
    out0 = tf.keras.layers.Conv3D(1,1,strides=1,name='regconv1')(inp0)
    out0 = tf.keras.layers.Flatten(name='flatten1')(out0)
    out0 = tf.keras.layers.Dense(units=1,name='age1')(out0)
    
    model = keras.Model(img0,out0,name='3DCNN_Metis_T1')
    return model

model = getCNN()
model.summary()
# Out:
# 2023-12-24 10:43:25.937446: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10534 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:0e:00.0, compute capability: 6.1
# Model: "3DCNN_Metis_T1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inp0 (InputLayer)           [(None, 91, 109, 91, 1)]  0
#
#  conv3d (Conv3D)             (None, 91, 109, 91, 32)   896
#
#  instance_normalization (Ins  (None, 91, 109, 91, 32)  0
#  tanceNormalization)
#
#  max_pooling3d (MaxPooling3D  (None, 45, 54, 45, 32)   0
#  )
#
#  tf.nn.relu (TFOpLambda)     (None, 45, 54, 45, 32)    0
#
#  conv3d_1 (Conv3D)           (None, 45, 54, 45, 64)    55360
#
#  instance_normalization_1 (I  (None, 45, 54, 45, 64)   0
#  nstanceNormalization)
#
#  max_pooling3d_1 (MaxPooling  (None, 22, 27, 22, 64)   0
#  3D)
#
#  tf.nn.relu_1 (TFOpLambda)   (None, 22, 27, 22, 64)    0
#
#  conv3d_2 (Conv3D)           (None, 22, 27, 22, 128)   221312
#
#  instance_normalization_2 (I  (None, 22, 27, 22, 128)  0
#  nstanceNormalization)
#
#  max_pooling3d_2 (MaxPooling  (None, 11, 13, 11, 128)  0
#  3D)
#
#  tf.nn.relu_2 (TFOpLambda)   (None, 11, 13, 11, 128)   0
#
#  conv3d_3 (Conv3D)           (None, 11, 13, 11, 256)   884992
#
#  instance_normalization_3 (I  (None, 11, 13, 11, 256)  0
#  nstanceNormalization)
#
#  max_pooling3d_3 (MaxPooling  (None, 5, 6, 5, 256)     0
#  3D)
#
#  tf.nn.relu_3 (TFOpLambda)   (None, 5, 6, 5, 256)      0
#
#  conv3d_4 (Conv3D)           (None, 5, 6, 5, 256)      1769728
#
#  instance_normalization_4 (I  (None, 5, 6, 5, 256)     0
#  nstanceNormalization)
#
#  max_pooling3d_4 (MaxPooling  (None, 2, 3, 2, 256)     0
#  3D)
#
#  tf.nn.relu_4 (TFOpLambda)   (None, 2, 3, 2, 256)      0
#
#  conv3d_5 (Conv3D)           (None, 2, 3, 2, 64)       16448
#
#  instance_normalization_5 (I  (None, 2, 3, 2, 64)      0
#  nstanceNormalization)
#
#  tf.nn.relu_5 (TFOpLambda)   (None, 2, 3, 2, 64)       0
#
#  average_pooling3d (AverageP  (None, 1, 1, 1, 64)      0
#  ooling3D)
#
#  drop (Dropout)              (None, 1, 1, 1, 64)       0
#
#  regconv1 (Conv3D)           (None, 1, 1, 1, 1)        65
#
#  flatten1 (Flatten)          (None, 1)                 0
#
#  age1 (Dense)                (None, 1)                 2
#
# =================================================================
# Total params: 2,948,803
# Trainable params: 2,948,803
# Non-trainable params: 0
# _________________________________________________________________

# %%
len(t1dwistr)
# Out:
# 458

# %%
dwi = df.loc[conddwi,:]

# %%
len(dwi)
# Out:
# 545

# %%
p = (np.ceil(0.7*len(dwi))-1).astype(int)
q = (np.ceil(0.9*len(dwi))-2).astype(int)
r = len(dwi)
train = dwi[:p]
test  = dwi[p:q]
val   = dwi[q:]
len(train), len(test), len(val)
# Out:
# (381, 108, 56)

# %%
count = 0
arr = []
for i in train['SubjID'].drop_duplicates():
    for j in val['SubjID'].drop_duplicates():
        if i == j:
            arr.append(i)
            count += 1
count
# Out:
# 0

# %%
class DataGenerator(tf.keras.utils.Sequence):
    def rotate(self,vol):
        def scipy_rotate(vol):
            angles = [-20,-10,-5,5,10,20]
            angle = pyrandom.choice(angles)
            vol = ndimage.rotate(vol,angle,reshape=False)
            vol[vol<0] = 0
            vol[vol>1] = 1
            return vol
        aug_vol = tf.numpy_function(scipy_rotate,[vol],tf.float32)
        return aug_vol

    def preprocessing(self,vol):
        if(self.isTrain):
            vol1 = self.rotate(vol)
            vol1 = tf.expand_dims(vol1,axis=3)
        else:
            vol1 = tf.expand_dims(vol,axis=3)
        return vol1
    
    def read_scan(self,path):
        scan = nib.load(path)
        volume = scan.get_fdata()
        min = np.amax(volume)
        max = np.amin(volume)
        volume = (volume - min) / (max - min)
        volume = volume.astype("float32")
        return volume

    def __init__(self, data, batch_size, sample_weights=None, isTrain=True):
        self.data = data
        self.batch_size = batch_size
        self.sample_weights = sample_weights
        self.isTrain = isTrain

    def __len__(self):
        return (np.ceil(len(self.data) / float(self.batch_size))).astype(np.int)

    def __getitem__(self, idx):
        dwi  = self.data['DWI_Matched_File_FA_Path_ENIGMATBSSspace_2MM'].tolist()
        labels = self.data['AGE_at_scan'].astype(np.float32)
        
        batch_dwi = dwi[idx * self.batch_size: (idx + 1) * self.batch_size]
        batch_y = labels[idx * self.batch_size: (idx + 1) * self.batch_size]
     
        dwi_imgs = np.asarray([self.preprocessing(self.read_scan(path)) for path in batch_dwi])
        
        return (dwi_imgs, np.array(batch_y))
    
    def on_epoch_end(self):
        if(self.isTrain):
            self.data = self.data.sample(frac=1)

# %%
dg_train = DataGenerator(train,batch_size)
dg_val = DataGenerator(val,batch_size,isTrain=False)
dg_test = DataGenerator(test,batch_size,isTrain=False)

# %%
model.compile(
    loss='mse',
    optimizer = keras.optimizers.AdamW(learning_rate=1e-2,weight_decay=1e-4),
    metrics = [tf.keras.metrics.RootMeanSquaredError(name='rmse'),tf.keras.metrics.MeanAbsoluteError(name='mae')]   
)
early = keras.callbacks.EarlyStopping(monitor='val_loss',patience = 20, verbose = 1, restore_best_weights = True)

history = model.fit(
    dg_train,
    validation_data = dg_val,
    epochs = 200,
    verbose = 1,
    callbacks = [early]
)

model.save('/lfs1/ashaji/Imputation_Problem/EMBC/DWI/modelonlyDWI')
# Out:
# /tmp/ipykernel_35829/855735005.py:37: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return (np.ceil(len(self.data) / float(self.batch_size))).astype(np.int)
# Epoch 1/200
# 2023-12-24 10:48:13.944332: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2023-12-24 10:48:17.297375: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-12-24 10:48:18.180195: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7f279817c160 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-24 10:48:18.180249: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# 2023-12-24 10:48:18.188097: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-12-24 10:48:18.513119: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 96/96 [==============================] - ETA: 0s - loss: 2167.0249 - rmse: 46.5513 - mae: 41.7450
# 2023-12-24 10:49:50.155346: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 96/96 [==============================] - 100s 961ms/step - loss: 2167.0249 - rmse: 46.5513 - mae: 41.7450 - val_loss: 111.5527 - val_rmse: 10.5618 - val_mae: 9.0037
# Epoch 2/200
# 96/96 [==============================] - 72s 752ms/step - loss: 204.4695 - rmse: 14.2993 - mae: 11.3535 - val_loss: 42.3929 - val_rmse: 6.5110 - val_mae: 5.2694
# Epoch 3/200
# 96/96 [==============================] - 72s 744ms/step - loss: 177.7992 - rmse: 13.3341 - mae: 10.7549 - val_loss: 43.2548 - val_rmse: 6.5768 - val_mae: 5.5182
# Epoch 4/200
# 96/96 [==============================] - 72s 748ms/step - loss: 183.8124 - rmse: 13.5577 - mae: 10.5928 - val_loss: 41.1963 - val_rmse: 6.4184 - val_mae: 5.3391
# Epoch 5/200
# 96/96 [==============================] - 73s 760ms/step - loss: 163.0244 - rmse: 12.7681 - mae: 10.3162 - val_loss: 46.5407 - val_rmse: 6.8221 - val_mae: 5.7284
# Epoch 6/200
# 96/96 [==============================] - 73s 761ms/step - loss: 148.2380 - rmse: 12.1753 - mae: 9.6867 - val_loss: 42.6663 - val_rmse: 6.5319 - val_mae: 5.2508
# Epoch 7/200
# 96/96 [==============================] - 72s 749ms/step - loss: 163.5297 - rmse: 12.7879 - mae: 10.0684 - val_loss: 41.0312 - val_rmse: 6.4056 - val_mae: 5.2139
# Epoch 8/200
# 96/96 [==============================] - 72s 752ms/step - loss: 167.2952 - rmse: 12.9343 - mae: 10.3510 - val_loss: 39.8846 - val_rmse: 6.3154 - val_mae: 5.1950
# Epoch 9/200
# 96/96 [==============================] - 72s 749ms/step - loss: 157.0113 - rmse: 12.5304 - mae: 10.0121 - val_loss: 49.7023 - val_rmse: 7.0500 - val_mae: 5.8627
# Epoch 10/200
# 96/96 [==============================] - 74s 770ms/step - loss: 149.8316 - rmse: 12.2406 - mae: 9.9422 - val_loss: 39.6747 - val_rmse: 6.2988 - val_mae: 5.1101
# Epoch 11/200
# 96/96 [==============================] - 74s 772ms/step - loss: 188.3493 - rmse: 13.7240 - mae: 11.2171 - val_loss: 42.8783 - val_rmse: 6.5481 - val_mae: 5.4684
# Epoch 12/200
# 96/96 [==============================] - 70s 730ms/step - loss: 155.4621 - rmse: 12.4684 - mae: 9.9598 - val_loss: 39.6955 - val_rmse: 6.3004 - val_mae: 4.9956
# Epoch 13/200
# 96/96 [==============================] - 71s 737ms/step - loss: 126.1103 - rmse: 11.2299 - mae: 8.8613 - val_loss: 37.7315 - val_rmse: 6.1426 - val_mae: 4.9358
# Epoch 60/200
# 96/96 [==============================] - 73s 754ms/step - loss: 65.5464 - rmse: 8.0961 - mae: 6.4512 - val_loss: 25.4166 - val_rmse: 5.0415 - val_mae: 3.8282
# Epoch 61/200
# 96/96 [==============================] - 72s 746ms/step - loss: 80.0758 - rmse: 8.9485 - mae: 6.9082 - val_loss: 29.7961 - val_rmse: 5.4586 - val_mae: 4.5124
# Epoch 62/200
# 96/96 [==============================] - 71s 741ms/step - loss: 57.2334 - rmse: 7.5653 - mae: 5.9934 - val_loss: 38.8203 - val_rmse: 6.2306 - val_mae: 5.2905
# Epoch 63/200
# 96/96 [==============================] - 73s 753ms/step - loss: 61.5844 - rmse: 7.8476 - mae: 6.2883 - val_loss: 25.8198 - val_rmse: 5.0813 - val_mae: 3.8580
# Epoch 64/200
# 96/96 [==============================] - 70s 726ms/step - loss: 55.7230 - rmse: 7.4648 - mae: 6.0153 - val_loss: 29.1153 - val_rmse: 5.3959 - val_mae: 4.0390
# Epoch 65/200
# 96/96 [==============================] - 71s 735ms/step - loss: 62.9495 - rmse: 7.9341 - mae: 6.1217 - val_loss: 22.0760 - val_rmse: 4.6985 - val_mae: 3.6801
# Epoch 66/200
# 96/96 [==============================] - 73s 753ms/step - loss: 62.7339 - rmse: 7.9205 - mae: 6.1689 - val_loss: 48.7347 - val_rmse: 6.9810 - val_mae: 5.4975
# Epoch 67/200
# 96/96 [==============================] - 72s 744ms/step - loss: 66.8597 - rmse: 8.1768 - mae: 6.6307 - val_loss: 25.1237 - val_rmse: 5.0124 - val_mae: 3.8590
# Epoch 68/200
# 96/96 [==============================] - 72s 750ms/step - loss: 52.7616 - rmse: 7.2637 - mae: 5.8117 - val_loss: 24.4956 - val_rmse: 4.9493 - val_mae: 3.8898
# Epoch 69/200
# 96/96 [==============================] - 73s 755ms/step - loss: 54.4413 - rmse: 7.3784 - mae: 5.9002 - val_loss: 24.8221 - val_rmse: 4.9822 - val_mae: 3.7916
# Epoch 70/200
# 96/96 [==============================] - 72s 745ms/step - loss: 51.7445 - rmse: 7.1934 - mae: 5.7517 - val_loss: 55.3913 - val_rmse: 7.4425 - val_mae: 6.0086
# Epoch 71/200
# 96/96 [==============================] - 71s 736ms/step - loss: 48.1877 - rmse: 6.9417 - mae: 5.5321 - val_loss: 24.3121 - val_rmse: 4.9307 - val_mae: 4.0087
# Epoch 72/200
# 96/96 [==============================] - 73s 755ms/step - loss: 48.1731 - rmse: 6.9407 - mae: 5.5178 - val_loss: 29.6244 - val_rmse: 5.4428 - val_mae: 4.2427
# Epoch 73/200
# 96/96 [==============================] - 73s 755ms/step - loss: 50.7024 - rmse: 7.1206 - mae: 5.6571 - val_loss: 23.2065 - val_rmse: 4.8173 - val_mae: 3.8406
# Epoch 74/200
# 96/96 [==============================] - 72s 746ms/step - loss: 55.4270 - rmse: 7.4449 - mae: 5.8357 - val_loss: 53.9363 - val_rmse: 7.3441 - val_mae: 5.8811
# Epoch 75/200
# Epoch 106/200
# 96/96 [==============================] - 72s 744ms/step - loss: 22.7997 - rmse: 4.7749 - mae: 3.7947 - val_loss: 33.3952 - val_rmse: 5.7789 - val_mae: 4.4780
# Epoch 107/200
# 96/96 [==============================] - 71s 738ms/step - loss: 23.3584 - rmse: 4.8331 - mae: 3.8782 - val_loss: 25.6824 - val_rmse: 5.0678 - val_mae: 4.0972
# Epoch 108/200
# 96/96 [==============================] - 71s 736ms/step - loss: 25.7441 - rmse: 5.0739 - mae: 4.1224 - val_loss: 30.6427 - val_rmse: 5.5356 - val_mae: 4.2627
# Epoch 109/200
# 96/96 [==============================] - 73s 760ms/step - loss: 18.5548 - rmse: 4.3075 - mae: 3.4493 - val_loss: 39.8734 - val_rmse: 6.3145 - val_mae: 4.8968
# Epoch 110/200
# 96/96 [==============================] - 74s 771ms/step - loss: 23.2019 - rmse: 4.8168 - mae: 3.8384 - val_loss: 20.8533 - val_rmse: 4.5665 - val_mae: 3.5026
# Epoch 111/200
# 96/96 [==============================] - 73s 754ms/step - loss: 20.6288 - rmse: 4.5419 - mae: 3.6325 - val_loss: 35.7100 - val_rmse: 5.9758 - val_mae: 4.6157
# Epoch 112/200
# 96/96 [==============================] - 72s 752ms/step - loss: 18.4379 - rmse: 4.2939 - mae: 3.3479 - val_loss: 34.1806 - val_rmse: 5.8464 - val_mae: 4.4711
# Epoch 113/200
# 96/96 [==============================] - 71s 737ms/step - loss: 20.1527 - rmse: 4.4892 - mae: 3.5030 - val_loss: 22.4072 - val_rmse: 4.7336 - val_mae: 3.6612
# Epoch 114/200
# 96/96 [==============================] - 71s 738ms/step - loss: 17.5463 - rmse: 4.1888 - mae: 3.1844 - val_loss: 22.6100 - val_rmse: 4.7550 - val_mae: 3.6939
# Epoch 115/200
# 96/96 [==============================] - 73s 756ms/step - loss: 19.3965 - rmse: 4.4041 - mae: 3.5324 - val_loss: 21.7154 - val_rmse: 4.6600 - val_mae: 3.5405
# Epoch 116/200
# 96/96 [==============================] - ETA: 0s - loss: 18.3037 - rmse: 4.2783 - mae: 3.2897Restoring model weights from the end of the best epoch: 96.
# 96/96 [==============================] - 72s 751ms/step - loss: 18.3037 - rmse: 4.2783 - mae: 3.2897 - val_loss: 24.9431 - val_rmse: 4.9943 - val_mae: 3.6812
# Epoch 116: early stopping
# 2023-12-24 13:07:49.855434: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,1,1,64]
# 	 [[{{node inputs}}]]
# 2023-12-24 13:07:50.941175: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,1,1,64]
# 	 [[{{node inputs}}]]
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 7). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lfs1/ashaji/Imputation_Problem/EMBC/DWI/modelonlyDWI/assets
# INFO:tensorflow:Assets written to: /lfs1/ashaji/Imputation_Problem/EMBC/DWI/modelonlyDWI/assets

# %%
model.evaluate(dg_test)
# Out:
# /tmp/ipykernel_35829/855735005.py:37: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return (np.ceil(len(self.data) / float(self.batch_size))).astype(np.int)
# 2023-12-24 13:12:02.164335: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 27/27 [==============================] - 18s 690ms/step - loss: 37.0199 - rmse: 6.0844 - mae: 4.8092
# [37.019893646240234, 6.084397315979004, 4.809215545654297]
