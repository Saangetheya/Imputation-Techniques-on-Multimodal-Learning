# %%
import pandas as pd
import tensorflow as tf
import numpy as np
import os
# Out:
# 2023-12-25 10:07:57.945517: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-25 10:07:58.747519: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def checkfilepath(filepath):
    return os.path.exists(filepath)

# %%
df = pd.read_excel('/lfs1/ashaji/Imputation_Problem/data/ADNI_final.xlsx', engine='openpyxl')
df['SubjID'].replace('',np.nan,inplace=True)
df['AGE_at_scan'].replace('',np.nan,inplace=True)
df.dropna(subset=['SubjID','AGE_at_scan'], inplace=True)
df = df.reset_index(drop=True)
df.loc[df['SEX']=='M','SEX'] = 1
df.loc[df['SEX']=='F','SEX'] = 0
condCN = df['DX'] == 'CN'
df = df.sort_values(by = ['SubjID'])
df = df.loc[condCN,:]
# df = df.sample(frac = 1)
df = df.reset_index(drop=True)

# %%
df['SEX'].replace('',np.nan,inplace=True)
df['CDRSB'].replace('',np.nan,inplace=True)
df['ADAS11'].replace('',np.nan,inplace=True)
df['ADAS13'].replace('',np.nan,inplace=True)
df['MMSE'].replace('',np.nan,inplace=True)
df['MOCA'].replace('',np.nan,inplace=True)
df['APOE A1'].replace('',np.nan,inplace=True)
df['APOE A2'].replace('',np.nan,inplace=True)

# %%
cond = [checkfilepath(str(x)) for x in df['ACCEL_DL_6DOF_2MM_T1']]
cond0 = df['ACCEL_Preprocessed for DL?']=='yes'

# %%
conddwi = [checkfilepath(str(x)) for x in df['DWI_Matched_File_FA_Path_ENIGMATBSSspace_2MM']]

# %%
len(conddwi)
# Out:
# 3288

# %%
cond2 = df['SEX'].isnull()
cond2 = np.invert(cond2)
cond3 = df['CDRSB'].isnull()
cond3 = np.invert(cond3)
cond4 = df['ADAS11'].isnull()
cond4 = np.invert(cond4)
cond5 = df['ADAS13'].isnull()
cond5 = np.invert(cond5)
cond6 = df['MMSE'].isnull()
cond6 = np.invert(cond6)
cond7 = df['MOCA'].isnull()
cond7 = np.invert(cond7)
cond8 = df['APOE A1'].isnull()
cond8 = np.invert(cond8)
cond9 = df['APOE A2'].isnull()
cond9 = np.invert(cond9)

# %%
condt1 = [cond[i] & cond0[i]  for i in range(len(cond))]

# %%
condstr = cond2 & cond3 & cond4 & cond5 & cond6 & cond7 & cond8 & cond9

# %%
len(condstr)
# Out:
# 3288

# %%
t1dwistr = df.loc[[(condt1[i] and conddwi[i] and condstr[i]) for i in range(len(condt1))]  , :]
len(t1dwistr)
# Out:
# 458

# %%
t1dwi_str = df.loc[[(condt1[i] and not conddwi[i] and condstr[i]) for i in range(len(condt1))] , :]
len(t1dwi_str)
# Out:
# 1255

# %%
t1dwi_str_ = df.loc[[(condt1[i] and not conddwi[i] and not condstr[i]) for i in range(len(condt1))] , :]
len(t1dwi_str_)
# Out:
# 329

# %%
t1_dwi_str = df.loc[[(not condt1[i] and not conddwi[i] and condstr[i]) for i in range(len(condt1))] , :]
len(t1_dwi_str)
# Out:
# 107

# %%
t1dwistr_ = df.loc[[(condt1[i] and conddwi[i] and not condstr[i]) for i in range(len(condt1))] , :]
len(t1dwistr_)
# Out:
# 74

# %%
t1_dwistr_ = df.loc[[(not condt1[i] and conddwi[i] and not condstr[i]) for i in range(len(condt1))] , :]
len(t1_dwistr_)
# Out:
# 0

# %%
t1_dwistr = df.loc[[(not condt1[i] and conddwi[i] and condstr[i]) for i in range(len(condt1))] , :]
len(t1_dwistr)
# Out:
# 13

# %%
t1dwi_str_ = df.loc[[(condt1[i] and not conddwi[i] and not condstr[i]) for i in range(len(condt1))] , :]
len(t1dwi_str_)
# Out:
# 329

# %%
df = df.reset_index(drop=True)
df.head(20)
# Out:
#         SubjID  RID                        NONACCEL_T1_SCAN_FILENAME  \
# 0   002_S_0295  295  002_S_0295_20060418_A1_T1_1.5T_nonaccel_Preproc
# 1   002_S_0295  295  002_S_0295_20061102_A1_T1_1.5T_nonaccel_Preproc
# 2   002_S_0295  295  002_S_0295_20070525_A1_T1_1.5T_nonaccel_Preproc
# 3   002_S_0295  295  002_S_0295_20080723_A1_T1_1.5T_nonaccel_Preproc
# 4   002_S_0295  295  002_S_0295_20090522_A1_T1_1.5T_nonaccel_Preproc
# 5   002_S_0295  295  002_S_0295_20100513_A1_T1_1.5T_nonaccel_Preproc
# 6   002_S_0295  295    002_S_0295_20110602_A2_T1_3T_nonaccel_Preproc
# 7   002_S_0295  295    002_S_0295_20120510_A2_T1_3T_nonaccel_Preproc
# 8   002_S_0413  413                                              NaN
# 9   002_S_0413  413    002_S_0413_20150609_A2_T1_3T_nonaccel_Preproc
# 10  002_S_0413  413    002_S_0413_20140501_A2_T1_3T_nonaccel_Preproc
# 11  002_S_0413  413    002_S_0413_20130510_A2_T1_3T_nonaccel_Preproc
# 12  002_S_0413  413    002_S_0413_20120515_A2_T1_3T_nonaccel_Preproc
# 13  002_S_0413  413    002_S_0413_20110616_A2_T1_3T_nonaccel_Preproc
# 14  002_S_0413  413                                              NaN
# 15  002_S_0413  413  002_S_0413_20090504_A1_T1_1.5T_nonaccel_Preproc
# 16  002_S_0413  413  002_S_0413_20080731_A1_T1_1.5T_nonaccel_Preproc
# 17  002_S_0413  413  002_S_0413_20070601_A1_T1_1.5T_nonaccel_Preproc
# 18  002_S_0413  413  002_S_0413_20061115_A1_T1_1.5T_nonaccel_Preproc
# 19  002_S_0413  413  002_S_0413_20100506_A1_T1_1.5T_nonaccel_Preproc
#
#     NONACCEL_T1_IMAGEID                         NONACCEL_Path to RAW nifti  \
# 0               45108.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 1               40966.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 2               64025.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 3              123685.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 4              150177.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 5              291869.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 6              241350.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 7              308078.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 8                   NaN                                                NaN
# 9              649030.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 10             424741.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 11             373133.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 12             312701.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 13             242895.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 14                  NaN                                                NaN
# 15             149740.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 16             120917.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 17              60008.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 18              79122.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 19             291873.0  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
#
#    NONACCEL_Preprocessed for DL?  \
# 0                            yes
# 1                            yes
# 2                            yes
# 3                            yes
# 4                            yes
# 5                            yes
# 6                            yes
# 7                            yes
# 8                            NaN
# 9                            yes
# 10                           yes
# 11                           yes
# 12                           yes
# 13                           yes
# 14                           NaN
# 15                           yes
# 16                           yes
# 17                           yes
# 18                           yes
# 19                           yes
#
#                               NONACCEL_DL_6DOF_2MM_T1  \
# 0   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 1   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 2   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 3   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 4   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 5   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 6   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 7   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 8                                                 NaN
# 9   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 10  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 11  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 12  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 13  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 14                                                NaN
# 15  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 16  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 17  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 18  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 19  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
#
#                             NONACCEL_DL_6DOF_2MM_MASK  \
# 0   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 1   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 2   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 3   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 4   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 5   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 6   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 7   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 8                                                 NaN
# 9   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 10  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 11  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 12  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 13  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 14                                                NaN
# 15  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 16  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 17  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 18  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 19  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
#
#                               NONACCEL_DL_6DOF_2MM_GM  \
# 0   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 1   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 2   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 3   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 4   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 5   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 6   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 7   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 8                                                 NaN
# 9   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 10  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 11  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 12  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 13  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 14                                                NaN
# 15  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 16  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 17  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 18  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
# 19  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...
#
#                               NONACCEL_DL_6DOF_2MM_WM  ...  \
# 0   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 1   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 2   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 3   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 4   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 5   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 6   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 7   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 8                                                 NaN  ...
# 9   /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 10  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 11  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 12  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 13  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 14                                                NaN  ...
# 15  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 16  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 17  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 18  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
# 19  /nas/bioint-data/neuroimaging-data/ADNI/6DOF/0...  ...
#
#              DWI_Matched_File_L1_Path_ENIGMATBSSspace  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#              DWI_Matched_File_MD_Path_ENIGMATBSSspace  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#              DWI_Matched_File_RD_Path_ENIGMATBSSspace  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                               T1_Path_ENIGMATBSSspace  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#          DWI_Matched_File_FA_Path_ENIGMATBSSspace_2MM  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#          DWI_Matched_File_L1_Path_ENIGMATBSSspace_2MM  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#          DWI_Matched_File_MD_Path_ENIGMATBSSspace_2MM  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#          DWI_Matched_File_RD_Path_ENIGMATBSSspace_2MM  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#                           T1_Path_ENIGMATBSSspace_2MM  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14  /nas/bioint-data/neuroimaging-data/ADNI/Organi...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
#    DWI Preprocessing Pipeline (old=ADNI2 - new=ADNI3)
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                               ADNI3
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                              ADNI3
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
#
# [20 rows x 121 columns]

# %%
import nibabel as nib
from tensorflow import keras
from tensorflow.keras import layers
import random as pyrandom
import tensorflow_addons as tfa
from tensorflow.keras.preprocessing import image_dataset_from_directory

import nibabel as nib
from scipy import ndimage
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, precision_recall_curve, accuracy_score, f1_score, precision_score, recall_score, auc, roc_auc_score
from sklearn.utils import class_weight
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]= "6"

physical_devices = tf.config.list_physical_devices('GPU')
print("Num GPUs Available: ", len(physical_devices))
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# /lfs1/ashaji/condawork/lib/python3.10/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(
# Num GPUs Available:  1

# %%
### Hyperparameter config

init_lr = 1e-4
epochs = 50
early_stop = 7
seed = 53
drop_out = 0.5
weight_decay = 1e-4

batch_size=4
test_batch_size=4

# %%
def getCNN(width = 91,height = 109, depth = 91):
    
    def conv_block(inp,filt,name):
        inp = tf.keras.layers.Conv3D(filt,3,strides=1,padding='same')(inp)
        inp = tfa.layers.InstanceNormalization(center=False,scale=False)(inp)
        inp = tf.keras.layers.MaxPooling3D(2,strides=2,padding = 'valid')(inp)
        inp = tf.nn.relu(inp)
        return inp
    
    img0 = tf.keras.Input((91,109,91,1),name='inp0')
    inp0 = conv_block(img0,32,'conv_block1')
    inp0 = conv_block(inp0,64,'conv_block2')
    inp0 = conv_block(inp0,128,'conv_block3')
    inp0 = conv_block(inp0,256,'conv_block4')
    inp0 = conv_block(inp0,256,'conv_block5')
    
    ##LAST LAYER
    
    inp0 = tf.keras.layers.Conv3D(64,1,strides=1,padding='same')(inp0)
    inp0 = tfa.layers.InstanceNormalization(center=False,scale=False)(inp0)
    inp0 = tf.nn.relu(inp0)
    inp0 = tf.keras.layers.AveragePooling3D(2,2,'valid')(inp0)
    
    inp0 = tf.keras.layers.Dropout(rate=0.5,name='drop')(inp0)
    
    out0 = tf.keras.layers.Conv3D(1,1,strides=1,name='regconv1')(inp0)
    out0 = tf.keras.layers.Flatten(name='flatten1')(out0)
    out0 = tf.keras.layers.Dense(units=1,name='age1')(out0)
    
    model = keras.Model(img0,out0,name='3DCNN_Metis_T1')
    return model

model = getCNN()
model.summary()
# Out:
# 2023-12-25 10:08:33.666946: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 10534 MB memory:  -> device: 0, name: NVIDIA GeForce GTX 1080 Ti, pci bus id: 0000:0e:00.0, compute capability: 6.1
# Model: "3DCNN_Metis_T1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inp0 (InputLayer)           [(None, 91, 109, 91, 1)]  0
#
#  conv3d (Conv3D)             (None, 91, 109, 91, 32)   896
#
#  instance_normalization (Ins  (None, 91, 109, 91, 32)  0
#  tanceNormalization)
#
#  max_pooling3d (MaxPooling3D  (None, 45, 54, 45, 32)   0
#  )
#
#  tf.nn.relu (TFOpLambda)     (None, 45, 54, 45, 32)    0
#
#  conv3d_1 (Conv3D)           (None, 45, 54, 45, 64)    55360
#
#  instance_normalization_1 (I  (None, 45, 54, 45, 64)   0
#  nstanceNormalization)
#
#  max_pooling3d_1 (MaxPooling  (None, 22, 27, 22, 64)   0
#  3D)
#
#  tf.nn.relu_1 (TFOpLambda)   (None, 22, 27, 22, 64)    0
#
#  conv3d_2 (Conv3D)           (None, 22, 27, 22, 128)   221312
#
#  instance_normalization_2 (I  (None, 22, 27, 22, 128)  0
#  nstanceNormalization)
#
#  max_pooling3d_2 (MaxPooling  (None, 11, 13, 11, 128)  0
#  3D)
#
#  tf.nn.relu_2 (TFOpLambda)   (None, 11, 13, 11, 128)   0
#
#  conv3d_3 (Conv3D)           (None, 11, 13, 11, 256)   884992
#
#  instance_normalization_3 (I  (None, 11, 13, 11, 256)  0
#  nstanceNormalization)
#
#  max_pooling3d_3 (MaxPooling  (None, 5, 6, 5, 256)     0
#  3D)
#
#  tf.nn.relu_3 (TFOpLambda)   (None, 5, 6, 5, 256)      0
#
#  conv3d_4 (Conv3D)           (None, 5, 6, 5, 256)      1769728
#
#  instance_normalization_4 (I  (None, 5, 6, 5, 256)     0
#  nstanceNormalization)
#
#  max_pooling3d_4 (MaxPooling  (None, 2, 3, 2, 256)     0
#  3D)
#
#  tf.nn.relu_4 (TFOpLambda)   (None, 2, 3, 2, 256)      0
#
#  conv3d_5 (Conv3D)           (None, 2, 3, 2, 64)       16448
#
#  instance_normalization_5 (I  (None, 2, 3, 2, 64)      0
#  nstanceNormalization)
#
#  tf.nn.relu_5 (TFOpLambda)   (None, 2, 3, 2, 64)       0
#
#  average_pooling3d (AverageP  (None, 1, 1, 1, 64)      0
#  ooling3D)
#
#  drop (Dropout)              (None, 1, 1, 1, 64)       0
#
#  regconv1 (Conv3D)           (None, 1, 1, 1, 1)        65
#
#  flatten1 (Flatten)          (None, 1)                 0
#
#  age1 (Dense)                (None, 1)                 2
#
# =================================================================
# Total params: 2,948,803
# Trainable params: 2,948,803
# Non-trainable params: 0
# _________________________________________________________________

# %%
len(t1dwistr)
# Out:
# 458

# %%
dwi = df.loc[conddwi,:]

# %%
len(dwi)
# Out:
# 545

# %%
train = dwi.drop(t1dwistr.index)

# %%
len(train)
# Out:
# 87

# %%
p = (np.ceil(0.7*len(t1dwistr))-1).astype(int)
q = (np.ceil(0.9*len(t1dwistr))-2).astype(int)
r = len(t1dwistr)
trainn = p
valn  = r - q
testn   = q - p
trainn, testn, valn
trainall = t1dwistr[:p]
testall  = t1dwistr[p:q]
valall   = t1dwistr[q:]
len(trainall), len(testall), len(valall)
# Out:
# (320, 91, 47)

# %%
datamix = [train,trainall,valall]
alltrain = pd.concat(datamix)
alltrain = alltrain.sort_values(by = ['SubjID'])

# %%
p = (np.ceil(0.8*len(alltrain))-1).astype(int)
p, len(alltrain)-p, 
# p = p - 2
# Out:
# (363, 91)

# %%
trainn = alltrain[:p]
valn   = alltrain[p:]
len(trainn),len(valn)
# Out:
# (363, 91)

# %%
count = 0
arr = []
for i in trainn['SubjID'].drop_duplicates():
    for j in testall['SubjID'].drop_duplicates():
        if i == j:
            arr.append(i)
            count += 1
count
# Out:
# 0

# %%
def checkTestAll(testall = testall):
    file = open('/lfs1/ashaji/Imputation_Problem/organized/DST/tester.txt','r')
    x = ''
    for i in testall['SubjID']:
        x += str(i+'\n')
    print(x==file.read())
checkTestAll()
# Out:
# True

# %%
class DataGenerator(tf.keras.utils.Sequence):
    def rotate(self,vol):
        def scipy_rotate(vol):
            angles = [-20,-10,-5,5,10,20]
            angle = pyrandom.choice(angles)
            vol = ndimage.rotate(vol,angle,reshape=False)
            vol[vol<0] = 0
            vol[vol>1] = 1
            return vol
        aug_vol = tf.numpy_function(scipy_rotate,[vol],tf.float32)
        return aug_vol

    def preprocessing(self,vol):
        if(self.isTrain):
            vol1 = self.rotate(vol)
            vol1 = tf.expand_dims(vol1,axis=3)
        else:
            vol1 = tf.expand_dims(vol,axis=3)
        return vol1
    
    def read_scan(self,path):
        scan = nib.load(path)
        volume = scan.get_fdata()
        min = np.amax(volume)
        max = np.amin(volume)
        volume = (volume - min) / (max - min)
        volume = volume.astype("float32")
        return volume

    def __init__(self, data, batch_size, sample_weights=None,isTrain=True):
        self.data = data
        self.batch_size = batch_size
        self.sample_weights = sample_weights
        self.isTrain = isTrain
        
    def __len__(self):
        return (np.ceil(len(self.data) / float(self.batch_size))).astype(np.int)

    def __getitem__(self, idx):
        dwi  = self.data['DWI_Matched_File_FA_Path_ENIGMATBSSspace_2MM'].tolist()
        labels = self.data['AGE_at_scan'].astype(np.float32)
        
        batch_dwi = dwi[idx * self.batch_size: (idx + 1) * self.batch_size]
        batch_y = labels[idx * self.batch_size: (idx + 1) * self.batch_size]
     
        dwi_imgs = np.asarray([self.preprocessing(self.read_scan(path)) for path in batch_dwi])
        
        return (dwi_imgs, np.array(batch_y))
    
    def on_epoch_end(self):
        if(self.isTrain):
            self.data = self.data.sample(frac=1)

# %%
dg_train = DataGenerator(trainn,batch_size)
dg_val = DataGenerator(valn,batch_size,isTrain=False)

# %%
dg_testall = DataGenerator(testall,batch_size,isTrain=False)

# %%
len(trainn),len(valn),len(testall)
# Out:
# (363, 91, 91)

# %%
model.compile(
    loss='mse',
    optimizer = keras.optimizers.AdamW(learning_rate=1e-3,weight_decay=1e-4),
    metrics = [tf.keras.metrics.RootMeanSquaredError(name='rmse'),tf.keras.metrics.MeanAbsoluteError(name='mae')]   
)
early = keras.callbacks.EarlyStopping(monitor='val_loss',patience = 20, verbose = 1, restore_best_weights = True)

history = model.fit(
    dg_train,
    validation_data = dg_val,
    epochs = 200,
    verbose = 1,
    callbacks = [early]
)

model.save('/lfs1/ashaji/Imputation_Problem/EMBC/DWIcom/modelonlyDWI')
# Out:
# /tmp/ipykernel_37501/1007520260.py:37: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return (np.ceil(len(self.data) / float(self.batch_size))).astype(np.int)
# Epoch 1/200
# 2023-12-25 10:13:26.597295: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2023-12-25 10:13:30.433336: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-12-25 10:13:31.314978: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7f442801e760 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-12-25 10:13:31.315045: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce GTX 1080 Ti, Compute Capability 6.1
# 2023-12-25 10:13:31.325623: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-12-25 10:13:31.650084: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 91/91 [==============================] - ETA: 0s - loss: 4815.9575 - rmse: 69.3971 - mae: 68.9800
# 2023-12-25 10:15:00.847503: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 91/91 [==============================] - 101s 1s/step - loss: 4815.9575 - rmse: 69.3971 - mae: 68.9800 - val_loss: 4346.0654 - val_rmse: 65.9247 - val_mae: 65.5970
# Epoch 2/200
# 91/91 [==============================] - 69s 758ms/step - loss: 4335.0200 - rmse: 65.8409 - mae: 65.3609 - val_loss: 3874.5454 - val_rmse: 62.2458 - val_mae: 61.8987
# Epoch 3/200
# 91/91 [==============================] - 71s 780ms/step - loss: 3834.0920 - rmse: 61.9200 - mae: 61.4009 - val_loss: 3370.9890 - val_rmse: 58.0602 - val_mae: 57.6880
# Epoch 4/200
# 91/91 [==============================] - 68s 748ms/step - loss: 3281.1194 - rmse: 57.2811 - mae: 56.6899 - val_loss: 2845.3694 - val_rmse: 53.3420 - val_mae: 52.9367
# Epoch 5/200
# 91/91 [==============================] - 70s 763ms/step - loss: 2738.0813 - rmse: 52.3267 - mae: 51.6253 - val_loss: 2326.8887 - val_rmse: 48.2378 - val_mae: 47.7892
# Epoch 6/200
# 91/91 [==============================] - 70s 766ms/step - loss: 2268.5962 - rmse: 47.6298 - mae: 46.6729 - val_loss: 1841.3674 - val_rmse: 42.9112 - val_mae: 42.4063
# Epoch 7/200
# 91/91 [==============================] - 71s 777ms/step - loss: 1758.5852 - rmse: 41.9355 - mae: 40.9230 - val_loss: 1402.0240 - val_rmse: 37.4436 - val_mae: 36.8641
# Epoch 8/200
# 91/91 [==============================] - 69s 758ms/step - loss: 1354.7367 - rmse: 36.8067 - mae: 35.3765 - val_loss: 1025.5083 - val_rmse: 32.0236 - val_mae: 31.3440
# Epoch 9/200
# 91/91 [==============================] - 69s 759ms/step - loss: 952.4913 - rmse: 30.8625 - mae: 29.1521 - val_loss: 721.6476 - val_rmse: 26.8635 - val_mae: 26.0498
# Epoch 10/200
# 91/91 [==============================] - 70s 769ms/step - loss: 732.2510 - rmse: 27.0601 - mae: 24.9680 - val_loss: 485.6123 - val_rmse: 22.0366 - val_mae: 21.0372
# Epoch 11/200
# 91/91 [==============================] - 70s 771ms/step - loss: 499.6489 - rmse: 22.3528 - mae: 19.5968 - val_loss: 322.7352 - val_rmse: 17.9648 - val_mae: 16.7238
# Epoch 12/200
# 91/91 [==============================] - 71s 782ms/step - loss: 404.7130 - rmse: 20.1175 - mae: 16.5865 - val_loss: 210.8399 - val_rmse: 14.5203 - val_mae: 13.0007
# Epoch 13/200
# 91/91 [==============================] - 69s 758ms/step - loss: 306.5937 - rmse: 17.5098 - mae: 14.5089 - val_loss: 142.0746 - val_rmse: 11.9195 - val_mae: 10.2376
# Epoch 14/200
# 91/91 [==============================] - 69s 755ms/step - loss: 260.4981 - rmse: 16.1400 - mae: 12.8881 - val_loss: 104.5350 - val_rmse: 10.2242 - val_mae: 8.3887
# Epoch 15/200
# 91/91 [==============================] - 70s 771ms/step - loss: 239.0071 - rmse: 15.4599 - mae: 12.2738 - val_loss: 77.9186 - val_rmse: 8.8272 - val_mae: 6.9397
# Epoch 16/200
# 91/91 [==============================] - 70s 763ms/step - loss: 227.9687 - rmse: 15.0986 - mae: 12.0802 - val_loss: 65.9668 - val_rmse: 8.1220 - val_mae: 6.2589
# Epoch 17/200
# 91/91 [==============================] - 67s 738ms/step - loss: 207.1297 - rmse: 14.3920 - mae: 11.2259 - val_loss: 54.4757 - val_rmse: 7.3808 - val_mae: 5.6232
# Epoch 18/200
# 91/91 [==============================] - 69s 758ms/step - loss: 199.7622 - rmse: 14.1337 - mae: 11.2947 - val_loss: 47.0252 - val_rmse: 6.8575 - val_mae: 5.3609
# Epoch 19/200
# 91/91 [==============================] - 69s 752ms/step - loss: 195.5862 - rmse: 13.9852 - mae: 11.1921 - val_loss: 46.2886 - val_rmse: 6.8036 - val_mae: 5.3508
# Epoch 20/200
# 91/91 [==============================] - 70s 763ms/step - loss: 199.9999 - rmse: 14.1421 - mae: 11.3186 - val_loss: 44.8772 - val_rmse: 6.6990 - val_mae: 5.3099
# Epoch 21/200
# 91/91 [==============================] - 69s 756ms/step - loss: 225.9198 - rmse: 15.0306 - mae: 12.2615 - val_loss: 43.3167 - val_rmse: 6.5815 - val_mae: 5.3262
# Epoch 22/200
# 91/91 [==============================] - 69s 758ms/step - loss: 206.4040 - rmse: 14.3668 - mae: 11.8098 - val_loss: 45.9855 - val_rmse: 6.7813 - val_mae: 5.3145
# Epoch 23/200
# 91/91 [==============================] - 68s 749ms/step - loss: 173.7001 - rmse: 13.1795 - mae: 10.4495 - val_loss: 66.2541 - val_rmse: 8.1397 - val_mae: 6.2741
# Epoch 24/200
# 91/91 [==============================] - 68s 747ms/step - loss: 209.4486 - rmse: 14.4723 - mae: 11.2852 - val_loss: 45.5737 - val_rmse: 6.7508 - val_mae: 5.3221
# Epoch 25/200
# 91/91 [==============================] - 71s 779ms/step - loss: 166.3418 - rmse: 12.8974 - mae: 10.4325 - val_loss: 44.4016 - val_rmse: 6.6634 - val_mae: 5.3039
# Epoch 26/200
# 91/91 [==============================] - 68s 745ms/step - loss: 179.9286 - rmse: 13.4137 - mae: 10.8123 - val_loss: 45.3124 - val_rmse: 6.7314 - val_mae: 5.3015
# Epoch 27/200
# 91/91 [==============================] - 70s 766ms/step - loss: 197.0807 - rmse: 14.0385 - mae: 11.1213 - val_loss: 45.5331 - val_rmse: 6.7478 - val_mae: 5.3173
# Epoch 28/200
# 91/91 [==============================] - 69s 759ms/step - loss: 193.4599 - rmse: 13.9090 - mae: 10.9624 - val_loss: 42.9529 - val_rmse: 6.5538 - val_mae: 5.3493
# Epoch 29/200
# 91/91 [==============================] - 70s 765ms/step - loss: 198.8127 - rmse: 14.1001 - mae: 11.0942 - val_loss: 43.1935 - val_rmse: 6.5722 - val_mae: 5.3303
# Epoch 30/200
# 91/91 [==============================] - 71s 775ms/step - loss: 173.4197 - rmse: 13.1689 - mae: 10.6250 - val_loss: 42.9312 - val_rmse: 6.5522 - val_mae: 5.3222
# Epoch 31/200
# 91/91 [==============================] - 69s 759ms/step - loss: 191.8709 - rmse: 13.8517 - mae: 11.1748 - val_loss: 42.7847 - val_rmse: 6.5410 - val_mae: 5.3595
# Epoch 32/200
# 91/91 [==============================] - 69s 761ms/step - loss: 223.1982 - rmse: 14.9398 - mae: 11.8711 - val_loss: 43.0329 - val_rmse: 6.5599 - val_mae: 5.3095
# Epoch 33/200
# 91/91 [==============================] - 70s 765ms/step - loss: 182.0881 - rmse: 13.4940 - mae: 10.8744 - val_loss: 42.8633 - val_rmse: 6.5470 - val_mae: 5.2877
# Epoch 34/200
# 91/91 [==============================] - 71s 776ms/step - loss: 203.1555 - rmse: 14.2533 - mae: 11.3324 - val_loss: 42.7787 - val_rmse: 6.5405 - val_mae: 5.4107
# Epoch 35/200
# 91/91 [==============================] - 69s 753ms/step - loss: 170.4025 - rmse: 13.0538 - mae: 10.3232 - val_loss: 43.3060 - val_rmse: 6.5807 - val_mae: 5.2562
# Epoch 36/200
# 91/91 [==============================] - 69s 762ms/step - loss: 215.1937 - rmse: 14.6695 - mae: 11.7521 - val_loss: 50.8454 - val_rmse: 7.1306 - val_mae: 5.4193
# Epoch 37/200
# 91/91 [==============================] - 70s 764ms/step - loss: 182.6158 - rmse: 13.5135 - mae: 10.5642 - val_loss: 43.7761 - val_rmse: 6.6163 - val_mae: 5.2420
# Epoch 38/200
# 91/91 [==============================] - 72s 785ms/step - loss: 209.2351 - rmse: 14.4650 - mae: 11.3855 - val_loss: 42.9998 - val_rmse: 6.5574 - val_mae: 5.2363
# Epoch 39/200
# 91/91 [==============================] - 70s 765ms/step - loss: 180.3091 - rmse: 13.4279 - mae: 10.5306 - val_loss: 41.8673 - val_rmse: 6.4705 - val_mae: 5.2976
# Epoch 40/200
# 91/91 [==============================] - 71s 773ms/step - loss: 193.3730 - rmse: 13.9059 - mae: 10.9113 - val_loss: 41.5465 - val_rmse: 6.4457 - val_mae: 5.2162
# Epoch 41/200
# 91/91 [==============================] - 69s 758ms/step - loss: 201.4280 - rmse: 14.1925 - mae: 11.4500 - val_loss: 41.7563 - val_rmse: 6.4619 - val_mae: 5.1747
# Epoch 42/200
# 91/91 [==============================] - 69s 759ms/step - loss: 198.8132 - rmse: 14.1001 - mae: 11.5486 - val_loss: 42.6614 - val_rmse: 6.5316 - val_mae: 5.1429
# Epoch 43/200
# 91/91 [==============================] - 69s 753ms/step - loss: 200.7122 - rmse: 14.1673 - mae: 11.4269 - val_loss: 55.6108 - val_rmse: 7.4573 - val_mae: 5.6783
# Epoch 44/200
# 91/91 [==============================] - 71s 774ms/step - loss: 174.2545 - rmse: 13.2005 - mae: 10.3883 - val_loss: 40.9611 - val_rmse: 6.4001 - val_mae: 5.1704
# Epoch 45/200
# 91/91 [==============================] - 69s 751ms/step - loss: 184.5880 - rmse: 13.5863 - mae: 10.9802 - val_loss: 44.1592 - val_rmse: 6.6452 - val_mae: 5.1630
# Epoch 46/200
# 91/91 [==============================] - 69s 753ms/step - loss: 179.8172 - rmse: 13.4096 - mae: 11.1333 - val_loss: 40.5868 - val_rmse: 6.3708 - val_mae: 5.1327
# Epoch 47/200
# 91/91 [==============================] - 69s 755ms/step - loss: 171.2015 - rmse: 13.0844 - mae: 10.4532 - val_loss: 40.4785 - val_rmse: 6.3623 - val_mae: 5.2233
# Epoch 48/200
# 91/91 [==============================] - 69s 758ms/step - loss: 206.9546 - rmse: 14.3859 - mae: 11.3082 - val_loss: 40.4375 - val_rmse: 6.3591 - val_mae: 5.2138
# Epoch 49/200
# 91/91 [==============================] - 70s 766ms/step - loss: 165.6239 - rmse: 12.8695 - mae: 10.0230 - val_loss: 47.2477 - val_rmse: 6.8737 - val_mae: 5.2448
# Epoch 50/200
# 91/91 [==============================] - 69s 764ms/step - loss: 191.3225 - rmse: 13.8319 - mae: 10.9569 - val_loss: 41.4580 - val_rmse: 6.4388 - val_mae: 5.3294
# Epoch 51/200
# 91/91 [==============================] - 68s 744ms/step - loss: 165.8693 - rmse: 12.8790 - mae: 10.2868 - val_loss: 47.4110 - val_rmse: 6.8856 - val_mae: 5.2498
# Epoch 52/200
# 91/91 [==============================] - 70s 771ms/step - loss: 170.7295 - rmse: 13.0663 - mae: 10.4344 - val_loss: 41.4886 - val_rmse: 6.4412 - val_mae: 5.0469
# Epoch 53/200
# 91/91 [==============================] - 71s 778ms/step - loss: 152.0039 - rmse: 12.3290 - mae: 9.8214 - val_loss: 40.1874 - val_rmse: 6.3394 - val_mae: 4.9313
# Epoch 54/200
# 91/91 [==============================] - 70s 762ms/step - loss: 163.0181 - rmse: 12.7679 - mae: 9.8915 - val_loss: 37.1710 - val_rmse: 6.0968 - val_mae: 4.9330
# Epoch 55/200
# 91/91 [==============================] - 70s 770ms/step - loss: 183.2123 - rmse: 13.5356 - mae: 10.8545 - val_loss: 36.4927 - val_rmse: 6.0409 - val_mae: 4.8244
# Epoch 56/200
# 91/91 [==============================] - 70s 766ms/step - loss: 177.8607 - rmse: 13.3364 - mae: 10.5784 - val_loss: 38.2599 - val_rmse: 6.1855 - val_mae: 5.0469
# Epoch 57/200
# 91/91 [==============================] - 69s 756ms/step - loss: 166.2998 - rmse: 12.8957 - mae: 10.2402 - val_loss: 38.6633 - val_rmse: 6.2180 - val_mae: 4.8230
# Epoch 58/200
# 91/91 [==============================] - 70s 764ms/step - loss: 161.3542 - rmse: 12.7025 - mae: 10.1255 - val_loss: 34.6535 - val_rmse: 5.8867 - val_mae: 4.6009
# Epoch 59/200
# 91/91 [==============================] - 69s 752ms/step - loss: 141.7424 - rmse: 11.9056 - mae: 9.5643 - val_loss: 35.7773 - val_rmse: 5.9814 - val_mae: 4.6874
# Epoch 60/200
# 91/91 [==============================] - 72s 784ms/step - loss: 176.3151 - rmse: 13.2784 - mae: 10.5768 - val_loss: 35.4980 - val_rmse: 5.9580 - val_mae: 4.7318
# Epoch 61/200
# 91/91 [==============================] - 70s 765ms/step - loss: 186.3762 - rmse: 13.6520 - mae: 10.7117 - val_loss: 46.5680 - val_rmse: 6.8241 - val_mae: 5.2514
# Epoch 62/200
# 91/91 [==============================] - 70s 772ms/step - loss: 168.0159 - rmse: 12.9621 - mae: 10.4113 - val_loss: 33.5164 - val_rmse: 5.7893 - val_mae: 4.5506
# Epoch 63/200
# 91/91 [==============================] - 69s 752ms/step - loss: 171.5707 - rmse: 13.0985 - mae: 10.5260 - val_loss: 36.0732 - val_rmse: 6.0061 - val_mae: 4.6510
# Epoch 64/200
# 91/91 [==============================] - 69s 761ms/step - loss: 146.8776 - rmse: 12.1193 - mae: 9.6693 - val_loss: 43.2679 - val_rmse: 6.5778 - val_mae: 5.0300
# Epoch 65/200
# 91/91 [==============================] - 71s 782ms/step - loss: 184.4684 - rmse: 13.5819 - mae: 10.5677 - val_loss: 33.4310 - val_rmse: 5.7820 - val_mae: 4.5458
# Epoch 66/200
# 91/91 [==============================] - 68s 749ms/step - loss: 168.9738 - rmse: 12.9990 - mae: 10.3776 - val_loss: 34.6232 - val_rmse: 5.8841 - val_mae: 4.6786
# Epoch 67/200
# 91/91 [==============================] - 70s 765ms/step - loss: 186.7182 - rmse: 13.6645 - mae: 11.1203 - val_loss: 34.0500 - val_rmse: 5.8352 - val_mae: 4.4702
# Epoch 68/200
# 91/91 [==============================] - 70s 766ms/step - loss: 180.4417 - rmse: 13.4329 - mae: 10.5643 - val_loss: 36.5666 - val_rmse: 6.0470 - val_mae: 4.6295
# Epoch 69/200
# 91/91 [==============================] - 70s 763ms/step - loss: 176.8670 - rmse: 13.2991 - mae: 10.7250 - val_loss: 33.7280 - val_rmse: 5.8076 - val_mae: 4.5405
# Epoch 70/200
# 91/91 [==============================] - 69s 761ms/step - loss: 152.9919 - rmse: 12.3690 - mae: 9.9688 - val_loss: 38.2824 - val_rmse: 6.1873 - val_mae: 4.7240
# Epoch 71/200
# 91/91 [==============================] - 70s 771ms/step - loss: 183.3970 - rmse: 13.5424 - mae: 10.7435 - val_loss: 34.4252 - val_rmse: 5.8673 - val_mae: 4.5484
# Epoch 72/200
# 91/91 [==============================] - 70s 762ms/step - loss: 159.9829 - rmse: 12.6484 - mae: 10.1681 - val_loss: 33.8790 - val_rmse: 5.8206 - val_mae: 4.5079
# Epoch 73/200
# 91/91 [==============================] - 70s 766ms/step - loss: 144.2010 - rmse: 12.0084 - mae: 9.9451 - val_loss: 31.4098 - val_rmse: 5.6044 - val_mae: 4.3442
# Epoch 74/200
# 91/91 [==============================] - 71s 778ms/step - loss: 123.3560 - rmse: 11.1066 - mae: 9.0144 - val_loss: 33.9380 - val_rmse: 5.8256 - val_mae: 4.5418
# Epoch 75/200
# 91/91 [==============================] - 69s 761ms/step - loss: 159.1073 - rmse: 12.6138 - mae: 10.0166 - val_loss: 31.6211 - val_rmse: 5.6233 - val_mae: 4.5025
# Epoch 76/200
# 91/91 [==============================] - 70s 773ms/step - loss: 144.9956 - rmse: 12.0414 - mae: 9.6954 - val_loss: 36.9034 - val_rmse: 6.0748 - val_mae: 4.7458
# Epoch 77/200
# 91/91 [==============================] - 69s 761ms/step - loss: 165.9286 - rmse: 12.8813 - mae: 10.3581 - val_loss: 29.7570 - val_rmse: 5.4550 - val_mae: 4.2569
# Epoch 78/200
# 91/91 [==============================] - 69s 758ms/step - loss: 162.7879 - rmse: 12.7588 - mae: 10.1294 - val_loss: 31.5171 - val_rmse: 5.6140 - val_mae: 4.3454
# Epoch 79/200
# 91/91 [==============================] - 68s 747ms/step - loss: 140.6586 - rmse: 11.8600 - mae: 9.4571 - val_loss: 29.7659 - val_rmse: 5.4558 - val_mae: 4.2111
# Epoch 80/200
# 91/91 [==============================] - 70s 764ms/step - loss: 149.8611 - rmse: 12.2418 - mae: 9.6913 - val_loss: 39.4077 - val_rmse: 6.2776 - val_mae: 5.1069
# Epoch 81/200
# 91/91 [==============================] - 67s 733ms/step - loss: 168.1965 - rmse: 12.9691 - mae: 10.5722 - val_loss: 29.0293 - val_rmse: 5.3879 - val_mae: 4.2482
# Epoch 82/200
# 91/91 [==============================] - 70s 769ms/step - loss: 152.3374 - rmse: 12.3425 - mae: 10.0620 - val_loss: 31.8020 - val_rmse: 5.6393 - val_mae: 4.4394
# Epoch 83/200
# 91/91 [==============================] - 70s 739ms/step - loss: 177.3792 - rmse: 13.3184 - mae: 10.7555 - val_loss: 29.7874 - val_rmse: 5.4578 - val_mae: 4.2837
# Epoch 84/200
# 91/91 [==============================] - 69s 756ms/step - loss: 137.3743 - rmse: 11.7207 - mae: 9.5806 - val_loss: 28.6698 - val_rmse: 5.3544 - val_mae: 4.2277
# Epoch 85/200
# 91/91 [==============================] - 69s 759ms/step - loss: 143.5317 - rmse: 11.9805 - mae: 9.7487 - val_loss: 29.8857 - val_rmse: 5.4668 - val_mae: 4.2690
# Epoch 86/200
# 91/91 [==============================] - 70s 767ms/step - loss: 149.0150 - rmse: 12.2072 - mae: 9.7443 - val_loss: 29.3405 - val_rmse: 5.4167 - val_mae: 4.2286
# Epoch 87/200
# 91/91 [==============================] - 70s 771ms/step - loss: 159.1110 - rmse: 12.6139 - mae: 10.1646 - val_loss: 29.7239 - val_rmse: 5.4520 - val_mae: 4.2470
# Epoch 88/200
# 91/91 [==============================] - 70s 766ms/step - loss: 151.6896 - rmse: 12.3162 - mae: 9.9011 - val_loss: 33.2152 - val_rmse: 5.7633 - val_mae: 4.4797
# Epoch 89/200
# 91/91 [==============================] - 69s 758ms/step - loss: 140.1983 - rmse: 11.8405 - mae: 9.4389 - val_loss: 27.4416 - val_rmse: 5.2385 - val_mae: 4.1742
# Epoch 90/200
# 91/91 [==============================] - 70s 769ms/step - loss: 137.2804 - rmse: 11.7167 - mae: 9.4364 - val_loss: 47.0676 - val_rmse: 6.8606 - val_mae: 5.5287
# Epoch 91/200
# 91/91 [==============================] - 67s 735ms/step - loss: 130.9123 - rmse: 11.4417 - mae: 9.1520 - val_loss: 31.1467 - val_rmse: 5.5809 - val_mae: 4.3817
# Epoch 92/200
# 91/91 [==============================] - 70s 771ms/step - loss: 144.2333 - rmse: 12.0097 - mae: 9.9765 - val_loss: 28.2016 - val_rmse: 5.3105 - val_mae: 4.2304
# Epoch 93/200
# 91/91 [==============================] - 70s 772ms/step - loss: 136.8497 - rmse: 11.6983 - mae: 9.4003 - val_loss: 35.2400 - val_rmse: 5.9363 - val_mae: 4.7005
# Epoch 94/200
# 91/91 [==============================] - 71s 780ms/step - loss: 122.9080 - rmse: 11.0864 - mae: 8.8490 - val_loss: 32.6546 - val_rmse: 5.7144 - val_mae: 4.5789
# Epoch 95/200
# 91/91 [==============================] - 69s 761ms/step - loss: 140.7589 - rmse: 11.8642 - mae: 9.5549 - val_loss: 27.8700 - val_rmse: 5.2792 - val_mae: 4.2253
# Epoch 96/200
# 91/91 [==============================] - 71s 781ms/step - loss: 145.1697 - rmse: 12.0486 - mae: 9.6537 - val_loss: 30.4025 - val_rmse: 5.5138 - val_mae: 4.3382
# Epoch 97/200
# 91/91 [==============================] - 69s 756ms/step - loss: 141.4073 - rmse: 11.8915 - mae: 9.2176 - val_loss: 30.0156 - val_rmse: 5.4786 - val_mae: 4.3292
# Epoch 98/200
# 91/91 [==============================] - 71s 782ms/step - loss: 131.9487 - rmse: 11.4869 - mae: 9.3418 - val_loss: 47.1573 - val_rmse: 6.8671 - val_mae: 5.5938
# Epoch 99/200
# 91/91 [==============================] - 70s 768ms/step - loss: 131.8799 - rmse: 11.4839 - mae: 9.2703 - val_loss: 29.3091 - val_rmse: 5.4138 - val_mae: 4.3616
# Epoch 100/200
# 91/91 [==============================] - 71s 776ms/step - loss: 135.7016 - rmse: 11.6491 - mae: 9.1531 - val_loss: 30.8693 - val_rmse: 5.5560 - val_mae: 4.3786
# Epoch 101/200
# 91/91 [==============================] - 69s 762ms/step - loss: 141.0925 - rmse: 11.8782 - mae: 9.7297 - val_loss: 27.3739 - val_rmse: 5.2320 - val_mae: 4.1730
# Epoch 102/200
# 91/91 [==============================] - 71s 782ms/step - loss: 136.7534 - rmse: 11.6942 - mae: 9.4647 - val_loss: 27.7824 - val_rmse: 5.2709 - val_mae: 4.1494
# Epoch 103/200
# 91/91 [==============================] - 70s 769ms/step - loss: 144.5856 - rmse: 12.0244 - mae: 9.5790 - val_loss: 36.2041 - val_rmse: 6.0170 - val_mae: 4.7575
# Epoch 104/200
# 91/91 [==============================] - 71s 779ms/step - loss: 131.8502 - rmse: 11.4826 - mae: 9.1993 - val_loss: 29.2732 - val_rmse: 5.4105 - val_mae: 4.2584
# Epoch 105/200
# 91/91 [==============================] - 70s 772ms/step - loss: 139.9028 - rmse: 11.8281 - mae: 9.3158 - val_loss: 33.2619 - val_rmse: 5.7673 - val_mae: 4.5236
# Epoch 106/200
# 91/91 [==============================] - 71s 780ms/step - loss: 110.9448 - rmse: 10.5330 - mae: 8.2858 - val_loss: 35.0274 - val_rmse: 5.9184 - val_mae: 4.6214
# Epoch 107/200
# 91/91 [==============================] - 71s 776ms/step - loss: 120.6447 - rmse: 10.9838 - mae: 8.7369 - val_loss: 28.5591 - val_rmse: 5.3441 - val_mae: 4.2303
# Epoch 108/200
# 91/91 [==============================] - 70s 766ms/step - loss: 119.3015 - rmse: 10.9225 - mae: 9.1496 - val_loss: 48.4458 - val_rmse: 6.9603 - val_mae: 5.6999
# Epoch 109/200
# 91/91 [==============================] - 70s 769ms/step - loss: 141.8790 - rmse: 11.9113 - mae: 9.5175 - val_loss: 29.2028 - val_rmse: 5.4040 - val_mae: 4.3413
# Epoch 110/200
# 91/91 [==============================] - 70s 768ms/step - loss: 140.9657 - rmse: 11.8729 - mae: 9.5236 - val_loss: 28.8249 - val_rmse: 5.3689 - val_mae: 4.3126
# Epoch 111/200
# 91/91 [==============================] - 70s 761ms/step - loss: 113.0514 - rmse: 10.6326 - mae: 8.6566 - val_loss: 33.2943 - val_rmse: 5.7701 - val_mae: 4.7170
# Epoch 112/200
# 91/91 [==============================] - 71s 775ms/step - loss: 121.3954 - rmse: 11.0180 - mae: 8.6837 - val_loss: 31.4971 - val_rmse: 5.6122 - val_mae: 4.5038
# Epoch 113/200
# 91/91 [==============================] - 71s 782ms/step - loss: 130.1877 - rmse: 11.4100 - mae: 9.0144 - val_loss: 32.8074 - val_rmse: 5.7278 - val_mae: 4.5039
# Epoch 114/200
# 91/91 [==============================] - 69s 759ms/step - loss: 126.9549 - rmse: 11.2674 - mae: 9.1061 - val_loss: 27.8532 - val_rmse: 5.2776 - val_mae: 4.2294
# Epoch 115/200
# 91/91 [==============================] - 70s 771ms/step - loss: 118.1074 - rmse: 10.8677 - mae: 8.6422 - val_loss: 34.5273 - val_rmse: 5.8760 - val_mae: 4.7152
# Epoch 116/200
# 91/91 [==============================] - 71s 775ms/step - loss: 119.7918 - rmse: 10.9449 - mae: 8.6991 - val_loss: 27.4163 - val_rmse: 5.2361 - val_mae: 4.1711
# Epoch 117/200
# 91/91 [==============================] - 69s 753ms/step - loss: 102.9067 - rmse: 10.1443 - mae: 7.9640 - val_loss: 26.3806 - val_rmse: 5.1362 - val_mae: 4.0936
# Epoch 118/200
# 91/91 [==============================] - 71s 775ms/step - loss: 126.7645 - rmse: 11.2590 - mae: 9.0368 - val_loss: 31.2845 - val_rmse: 5.5933 - val_mae: 4.4985
# Epoch 119/200
# 91/91 [==============================] - 69s 763ms/step - loss: 109.7502 - rmse: 10.4762 - mae: 8.4661 - val_loss: 27.8646 - val_rmse: 5.2787 - val_mae: 4.2993
# Epoch 120/200
# 91/91 [==============================] - 69s 760ms/step - loss: 109.9045 - rmse: 10.4835 - mae: 8.5959 - val_loss: 41.5422 - val_rmse: 6.4453 - val_mae: 5.1139
# Epoch 121/200
# 91/91 [==============================] - 70s 772ms/step - loss: 120.1119 - rmse: 10.9596 - mae: 8.7908 - val_loss: 30.0233 - val_rmse: 5.4793 - val_mae: 4.4116
# Epoch 122/200
# 91/91 [==============================] - 69s 757ms/step - loss: 123.0718 - rmse: 11.0938 - mae: 8.9756 - val_loss: 28.1139 - val_rmse: 5.3023 - val_mae: 4.2762
# Epoch 123/200
# 91/91 [==============================] - 71s 779ms/step - loss: 118.0246 - rmse: 10.8639 - mae: 8.8136 - val_loss: 26.6796 - val_rmse: 5.1652 - val_mae: 4.1062
# Epoch 124/200
# 91/91 [==============================] - 69s 760ms/step - loss: 114.1684 - rmse: 10.6850 - mae: 8.3713 - val_loss: 28.3728 - val_rmse: 5.3266 - val_mae: 4.2827
# Epoch 125/200
# 91/91 [==============================] - 69s 758ms/step - loss: 109.1728 - rmse: 10.4486 - mae: 8.5508 - val_loss: 36.8996 - val_rmse: 6.0745 - val_mae: 5.0184
# Epoch 126/200
# 91/91 [==============================] - 69s 754ms/step - loss: 105.7408 - rmse: 10.2830 - mae: 8.0446 - val_loss: 28.3034 - val_rmse: 5.3201 - val_mae: 4.4121
# Epoch 127/200
# 91/91 [==============================] - 71s 775ms/step - loss: 117.7187 - rmse: 10.8498 - mae: 8.5381 - val_loss: 38.0432 - val_rmse: 6.1679 - val_mae: 4.9364
# Epoch 128/200
# 91/91 [==============================] - 70s 772ms/step - loss: 104.6954 - rmse: 10.2321 - mae: 8.1472 - val_loss: 27.3972 - val_rmse: 5.2342 - val_mae: 4.1589
# Epoch 129/200
# 91/91 [==============================] - 70s 764ms/step - loss: 101.9262 - rmse: 10.0959 - mae: 7.8556 - val_loss: 27.4843 - val_rmse: 5.2425 - val_mae: 4.1937
# Epoch 130/200
# 91/91 [==============================] - 68s 751ms/step - loss: 101.6502 - rmse: 10.0822 - mae: 8.0217 - val_loss: 28.7280 - val_rmse: 5.3598 - val_mae: 4.2683
# Epoch 131/200
# 91/91 [==============================] - 71s 775ms/step - loss: 106.0672 - rmse: 10.2989 - mae: 8.2390 - val_loss: 26.9639 - val_rmse: 5.1927 - val_mae: 4.2300
# Epoch 132/200
# 91/91 [==============================] - 69s 759ms/step - loss: 110.9026 - rmse: 10.5310 - mae: 8.2535 - val_loss: 28.4572 - val_rmse: 5.3345 - val_mae: 4.3299
# Epoch 133/200
# 91/91 [==============================] - 71s 775ms/step - loss: 104.7310 - rmse: 10.2338 - mae: 8.2211 - val_loss: 28.1481 - val_rmse: 5.3055 - val_mae: 4.2702
# Epoch 134/200
# 91/91 [==============================] - 69s 758ms/step - loss: 106.1673 - rmse: 10.3038 - mae: 8.3360 - val_loss: 30.2427 - val_rmse: 5.4993 - val_mae: 4.4446
# Epoch 135/200
# 91/91 [==============================] - 71s 780ms/step - loss: 106.8143 - rmse: 10.3351 - mae: 8.2600 - val_loss: 28.9013 - val_rmse: 5.3760 - val_mae: 4.3761
# Epoch 136/200
# 91/91 [==============================] - 70s 772ms/step - loss: 108.1480 - rmse: 10.3994 - mae: 8.1582 - val_loss: 27.9944 - val_rmse: 5.2910 - val_mae: 4.2162
# Epoch 137/200
# 91/91 [==============================] - ETA: 0s - loss: 94.7701 - rmse: 9.7350 - mae: 7.8922Restoring model weights from the end of the best epoch: 117.
# 91/91 [==============================] - 70s 771ms/step - loss: 94.7701 - rmse: 9.7350 - mae: 7.8922 - val_loss: 39.0568 - val_rmse: 6.2495 - val_mae: 4.9959
# Epoch 137: early stopping
# 2023-12-25 12:53:20.746148: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,1,1,64]
# 	 [[{{node inputs}}]]
# 2023-12-25 12:53:21.816756: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'inputs' with dtype float and shape [?,1,1,1,64]
# 	 [[{{node inputs}}]]
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 7). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /lfs1/ashaji/Imputation_Problem/EMBC/DWIcom/modelonlyDWI/assets
# INFO:tensorflow:Assets written to: /lfs1/ashaji/Imputation_Problem/EMBC/DWIcom/modelonlyDWI/assets

# %%
model = keras.models.load_model('/lfs1/ashaji/Imputation_Problem/EMBC/DWIcom/modelonlyDWI')
model.evaluate(dg_testall)
# Out:
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# WARNING:root:The given value for groups will be overwritten.
# /tmp/ipykernel_37501/1007520260.py:37: DeprecationWarning: `np.int` is a deprecated alias for the builtin `int`. To silence this warning, use `int` by itself. Doing this will not modify any behavior and is safe. When replacing `np.int`, you may wish to use e.g. `np.int64` or `np.int32` to specify the precision. If you wish to review your current use, check the release note link for additional information.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   return (np.ceil(len(self.data) / float(self.batch_size))).astype(np.int)
# 2023-12-25 13:24:08.041373: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 23/23 [==============================] - 4s 168ms/step - loss: 32.6573 - rmse: 5.7147 - mae: 4.3846
# [32.6573486328125, 5.71466064453125, 4.384593963623047]
